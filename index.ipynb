# %% [markdown]
# <center> <h1>Pokemon/Dictionary Warmup</h1> </center>

# %% [markdown]
# ![Pokeball](https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSvFguv_4hYhwny0d7KdBcFYHYCZ0j2uEBtr3aYmJHqNKecqEsi&usqp=CAU)

# %% [markdown]
# Joél is currently playing the Pokemon Crystal video game.
#
# Joél takes pokemon very seriously so they have downloaded [The Complete Pokemon Dataset](https://www.kaggle.com/rounakbanik/pokemon) from Kaggle and they need some help organizing the data.
#
# Let's use our dictionary parsing skills to help Joél out!

# %% [markdown]
# **In the cell below,** we import the Pokemon Dataset.
#
# *Don't worry about this code for now. Just run the cell ☺️*

# %%
import json
import os

path = os.path.join('data', 'pokemon.json')
with open(path, 'r') as fp:
    data = json.load(fp)

# %% [markdown]
# Let's take a look at the data we just imported.

# %%
data
# Out:
# {'Bulbasaur': {'abilities': "['Overgrow', 'Chlorophyll']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 49,
#    'defense': 49,
#    'experience_growth': 1059860,
#    'height_m': 0.7,
#    'hp': 45,
#    'sp_attack': 65,
#    'sp_defense': 65,
#    'speed': 45,
#    'type1': 'grass',
#    'type2': 'poison',
#    'weight_kg': 6.9},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 318,
#    'capture_rate': '45'},
#   'meta_data': 1},
#  'Ivysaur': {'abilities': "['Overgrow', 'Chlorophyll']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 62,
#    'defense': 63,
#    'experience_growth': 1059860,
#    'height_m': 1.0,
#    'hp': 60,
#    'sp_attack': 80,
#    'sp_defense': 80,
#    'speed': 60,
#    'type1': 'grass',
#    'type2': 'poison',
#    'weight_kg': 13.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 405,
#    'capture_rate': '45'},
#   'meta_data': 2},
#  'Venusaur': {'abilities': "['Overgrow', 'Chlorophyll']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 100,
#    'defense': 123,
#    'experience_growth': 1059860,
#    'height_m': 2.0,
#    'hp': 80,
#    'sp_attack': 122,
#    'sp_defense': 120,
#    'speed': 80,
#    'type1': 'grass',
#    'type2': 'poison',
#    'weight_kg': 100.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 625,
#    'capture_rate': '45'},
#   'meta_data': 3},
#  'Charmander': {'abilities': "['Blaze', 'Solar Power']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 0.5,
#    'water': 2.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 52,
#    'defense': 43,
#    'experience_growth': 1059860,
#    'height_m': 0.6,
#    'hp': 39,
#    'sp_attack': 60,
#    'sp_defense': 50,
#    'speed': 65,
#    'type1': 'fire',
#    'type2': nan,
#    'weight_kg': 8.5},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 309,
#    'capture_rate': '45'},
#   'meta_data': 4},
#  'Charmeleon': {'abilities': "['Blaze', 'Solar Power']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 0.5,
#    'water': 2.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 64,
#    'defense': 58,
#    'experience_growth': 1059860,
#    'height_m': 1.1,
#    'hp': 58,
#    'sp_attack': 80,
#    'sp_defense': 65,
#    'speed': 80,
#    'type1': 'fire',
#    'type2': nan,
#    'weight_kg': 19.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 405,
#    'capture_rate': '45'},
#   'meta_data': 5},
#  'Charizard': {'abilities': "['Blaze', 'Solar Power']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 0.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 4.0,
#    'steel': 0.5,
#    'water': 2.0,
#    'bug': 0.25,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 104,
#    'defense': 78,
#    'experience_growth': 1059860,
#    'height_m': 1.7,
#    'hp': 78,
#    'sp_attack': 159,
#    'sp_defense': 115,
#    'speed': 100,
#    'type1': 'fire',
#    'type2': 'flying',
#    'weight_kg': 90.5},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 634,
#    'capture_rate': '45'},
#   'meta_data': 6},
#  'Squirtle': {'abilities': "['Torrent', 'Rain Dish']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 0.5,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 48,
#    'defense': 65,
#    'experience_growth': 1059860,
#    'height_m': 0.5,
#    'hp': 44,
#    'sp_attack': 50,
#    'sp_defense': 64,
#    'speed': 43,
#    'type1': 'water',
#    'type2': nan,
#    'weight_kg': 9.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 314,
#    'capture_rate': '45'},
#   'meta_data': 7},
#  'Wartortle': {'abilities': "['Torrent', 'Rain Dish']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 0.5,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 63,
#    'defense': 80,
#    'experience_growth': 1059860,
#    'height_m': 1.0,
#    'hp': 59,
#    'sp_attack': 65,
#    'sp_defense': 80,
#    'speed': 58,
#    'type1': 'water',
#    'type2': nan,
#    'weight_kg': 22.5},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 405,
#    'capture_rate': '45'},
#   'meta_data': 8},
#  'Blastoise': {'abilities': "['Torrent', 'Rain Dish']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 0.5,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 103,
#    'defense': 120,
#    'experience_growth': 1059860,
#    'height_m': 1.6,
#    'hp': 79,
#    'sp_attack': 135,
#    'sp_defense': 115,
#    'speed': 78,
#    'type1': 'water',
#    'type2': nan,
#    'weight_kg': 85.5},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 630,
#    'capture_rate': '45'},
#   'meta_data': 9},
#  'Caterpie': {'abilities': "['Shield Dust', 'Run Away']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 0.5,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 30,
#    'defense': 35,
#    'experience_growth': 1000000,
#    'height_m': 0.3,
#    'hp': 45,
#    'sp_attack': 20,
#    'sp_defense': 20,
#    'speed': 45,
#    'type1': 'bug',
#    'type2': nan,
#    'weight_kg': 2.9},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 195,
#    'capture_rate': '255'},
#   'meta_data': 10},
#  'Metapod': {'abilities': "['Shed Skin']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 0.5,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 20,
#    'defense': 55,
#    'experience_growth': 1000000,
#    'height_m': 0.7,
#    'hp': 50,
#    'sp_attack': 25,
#    'sp_defense': 25,
#    'speed': 30,
#    'type1': 'bug',
#    'type2': nan,
#    'weight_kg': 9.9},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 205,
#    'capture_rate': '120'},
#   'meta_data': 11},
#  'Butterfree': {'abilities': "['Compoundeyes', 'Tinted Lens']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 0.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 4.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 0.25,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 45,
#    'defense': 50,
#    'experience_growth': 1000000,
#    'height_m': 1.1,
#    'hp': 60,
#    'sp_attack': 90,
#    'sp_defense': 80,
#    'speed': 70,
#    'type1': 'bug',
#    'type2': 'flying',
#    'weight_kg': 32.0},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 395,
#    'capture_rate': '45'},
#   'meta_data': 12},
#  'Weedle': {'abilities': "['Shield Dust', 'Run Away']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.25,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 35,
#    'defense': 30,
#    'experience_growth': 1000000,
#    'height_m': 0.3,
#    'hp': 40,
#    'sp_attack': 20,
#    'sp_defense': 20,
#    'speed': 50,
#    'type1': 'bug',
#    'type2': 'poison',
#    'weight_kg': 3.2},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 195,
#    'capture_rate': '255'},
#   'meta_data': 13},
#  'Kakuna': {'abilities': "['Shed Skin']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.25,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 25,
#    'defense': 50,
#    'experience_growth': 1000000,
#    'height_m': 0.6,
#    'hp': 45,
#    'sp_attack': 25,
#    'sp_defense': 25,
#    'speed': 35,
#    'type1': 'bug',
#    'type2': 'poison',
#    'weight_kg': 10.0},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 205,
#    'capture_rate': '120'},
#   'meta_data': 14},
#  'Beedrill': {'abilities': "['Swarm', 'Sniper']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.25,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 150,
#    'defense': 40,
#    'experience_growth': 1000000,
#    'height_m': 1.0,
#    'hp': 65,
#    'sp_attack': 15,
#    'sp_defense': 80,
#    'speed': 145,
#    'type1': 'bug',
#    'type2': 'poison',
#    'weight_kg': 29.5},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 495,
#    'capture_rate': '45'},
#   'meta_data': 15},
#  'Pidgey': {'abilities': "['Keen Eye', 'Tangled Feet', 'Big Pecks']",
#   'weakness': {'ghost': 0.0,
#    'grass': 0.5,
#    'ground': 0.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 45,
#    'defense': 40,
#    'experience_growth': 1059860,
#    'height_m': 0.3,
#    'hp': 40,
#    'sp_attack': 35,
#    'sp_defense': 35,
#    'speed': 56,
#    'type1': 'normal',
#    'type2': 'flying',
#    'weight_kg': 1.8},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 251,
#    'capture_rate': '255'},
#   'meta_data': 16},
#  'Pidgeotto': {'abilities': "['Keen Eye', 'Tangled Feet', 'Big Pecks']",
#   'weakness': {'ghost': 0.0,
#    'grass': 0.5,
#    'ground': 0.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 60,
#    'defense': 55,
#    'experience_growth': 1059860,
#    'height_m': 1.1,
#    'hp': 63,
#    'sp_attack': 50,
#    'sp_defense': 50,
#    'speed': 71,
#    'type1': 'normal',
#    'type2': 'flying',
#    'weight_kg': 30.0},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 349,
#    'capture_rate': '120'},
#   'meta_data': 17},
#  'Pidgeot': {'abilities': "['Keen Eye', 'Tangled Feet', 'Big Pecks']",
#   'weakness': {'ghost': 0.0,
#    'grass': 0.5,
#    'ground': 0.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 80,
#    'defense': 80,
#    'experience_growth': 1059860,
#    'height_m': 1.5,
#    'hp': 83,
#    'sp_attack': 135,
#    'sp_defense': 80,
#    'speed': 121,
#    'type1': 'normal',
#    'type2': 'flying',
#    'weight_kg': 39.5},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 579,
#    'capture_rate': '45'},
#   'meta_data': 18},
#  'Rattata': {'abilities': "['Run Away', 'Guts', 'Hustle', 'Gluttony', 'Hustle', 'Thick Fat']",
#   'weakness': {'ghost': 0.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 2.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 56,
#    'defense': 35,
#    'experience_growth': 1000000,
#    'height_m': nan,
#    'hp': 30,
#    'sp_attack': 25,
#    'sp_defense': 35,
#    'speed': 72,
#    'type1': 'normal',
#    'type2': 'dark',
#    'weight_kg': nan},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 253,
#    'capture_rate': '255'},
#   'meta_data': 19},
#  'Raticate': {'abilities': "['Run Away', 'Guts', 'Hustle', 'Gluttony', 'Hustle', 'Thick Fat']",
#   'weakness': {'ghost': 0.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 2.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 71,
#    'defense': 70,
#    'experience_growth': 1000000,
#    'height_m': nan,
#    'hp': 75,
#    'sp_attack': 40,
#    'sp_defense': 80,
#    'speed': 77,
#    'type1': 'normal',
#    'type2': 'dark',
#    'weight_kg': nan},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 413,
#    'capture_rate': '127'},
#   'meta_data': 20},
#  'Spearow': {'abilities': "['Keen Eye', 'Sniper']",
#   'weakness': {'ghost': 0.0,
#    'grass': 0.5,
#    'ground': 0.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 60,
#    'defense': 30,
#    'experience_growth': 1000000,
#    'height_m': 0.3,
#    'hp': 40,
#    'sp_attack': 31,
#    'sp_defense': 31,
#    'speed': 70,
#    'type1': 'normal',
#    'type2': 'flying',
#    'weight_kg': 2.0},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 262,
#    'capture_rate': '255'},
#   'meta_data': 21},
#  'Fearow': {'abilities': "['Keen Eye', 'Sniper']",
#   'weakness': {'ghost': 0.0,
#    'grass': 0.5,
#    'ground': 0.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 90,
#    'defense': 65,
#    'experience_growth': 1000000,
#    'height_m': 1.2,
#    'hp': 65,
#    'sp_attack': 61,
#    'sp_defense': 61,
#    'speed': 100,
#    'type1': 'normal',
#    'type2': 'flying',
#    'weight_kg': 38.0},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 442,
#    'capture_rate': '90'},
#   'meta_data': 22},
#  'Ekans': {'abilities': "['Intimidate', 'Shed Skin', 'Unnerve']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 60,
#    'defense': 44,
#    'experience_growth': 1000000,
#    'height_m': 2.0,
#    'hp': 35,
#    'sp_attack': 40,
#    'sp_defense': 54,
#    'speed': 55,
#    'type1': 'poison',
#    'type2': nan,
#    'weight_kg': 6.9},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 288,
#    'capture_rate': '255'},
#   'meta_data': 23},
#  'Arbok': {'abilities': "['Intimidate', 'Shed Skin', 'Unnerve']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 95,
#    'defense': 69,
#    'experience_growth': 1000000,
#    'height_m': 3.5,
#    'hp': 60,
#    'sp_attack': 65,
#    'sp_defense': 79,
#    'speed': 80,
#    'type1': 'poison',
#    'type2': nan,
#    'weight_kg': 65.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 448,
#    'capture_rate': '90'},
#   'meta_data': 24},
#  'Pikachu': {'abilities': "['Static', 'Lightningrod']",
#   'weakness': {'ghost': 1.0,
#    'grass': 1.0,
#    'ground': 2.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 0.5,
#    'water': 1.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 0.5,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 55,
#    'defense': 40,
#    'experience_growth': 1000000,
#    'height_m': 0.4,
#    'hp': 35,
#    'sp_attack': 50,
#    'sp_defense': 50,
#    'speed': 90,
#    'type1': 'electric',
#    'type2': nan,
#    'weight_kg': 6.0},
#   'base': {'base_egg_steps': 2560,
#    'base_happiness': 70,
#    'base_total': 320,
#    'capture_rate': '190'},
#   'meta_data': 25},
#  'Raichu': {'abilities': "['Static', 'Lightningrod', 'Surge Surfer']",
#   'weakness': {'ghost': 1.0,
#    'grass': 1.0,
#    'ground': 2.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 0.5,
#    'water': 1.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 0.5,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 85,
#    'defense': 50,
#    'experience_growth': 1000000,
#    'height_m': nan,
#    'hp': 60,
#    'sp_attack': 95,
#    'sp_defense': 85,
#    'speed': 110,
#    'type1': 'electric',
#    'type2': 'electric',
#    'weight_kg': nan},
#   'base': {'base_egg_steps': 2560,
#    'base_happiness': 70,
#    'base_total': 485,
#    'capture_rate': '75'},
#   'meta_data': 26},
#  'Sandshrew': {'abilities': "['Sand Veil', 'Sand Rush', 'Snow Cloak', 'Slush Rush']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 1.0,
#    'rock': 0.5,
#    'steel': 1.0,
#    'water': 2.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.0},
#   'stats': {'attack': 75,
#    'defense': 90,
#    'experience_growth': 1000000,
#    'height_m': nan,
#    'hp': 50,
#    'sp_attack': 10,
#    'sp_defense': 35,
#    'speed': 40,
#    'type1': 'ground',
#    'type2': 'ice',
#    'weight_kg': nan},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 300,
#    'capture_rate': '255'},
#   'meta_data': 27},
#  'Sandslash': {'abilities': "['Sand Veil', 'Sand Rush', 'Snow Cloak', 'Slush Rush']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 1.0,
#    'rock': 0.5,
#    'steel': 1.0,
#    'water': 2.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.0},
#   'stats': {'attack': 100,
#    'defense': 120,
#    'experience_growth': 1000000,
#    'height_m': nan,
#    'hp': 75,
#    'sp_attack': 25,
#    'sp_defense': 65,
#    'speed': 65,
#    'type1': 'ground',
#    'type2': 'ice',
#    'weight_kg': nan},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 450,
#    'capture_rate': '90'},
#   'meta_data': 28},
#  'Nidoran♀': {'abilities': "['Poison Point', 'Rivalry', 'Hustle']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 47,
#    'defense': 52,
#    'experience_growth': 1059860,
#    'height_m': 0.4,
#    'hp': 55,
#    'sp_attack': 40,
#    'sp_defense': 40,
#    'speed': 41,
#    'type1': 'poison',
#    'type2': nan,
#    'weight_kg': 7.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 275,
#    'capture_rate': '235'},
#   'meta_data': 29},
#  'Nidorina': {'abilities': "['Poison Point', 'Rivalry', 'Hustle']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 62,
#    'defense': 67,
#    'experience_growth': 1059860,
#    'height_m': 0.8,
#    'hp': 70,
#    'sp_attack': 55,
#    'sp_defense': 55,
#    'speed': 56,
#    'type1': 'poison',
#    'type2': nan,
#    'weight_kg': 20.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 365,
#    'capture_rate': '120'},
#   'meta_data': 30},
#  'Nidoqueen': {'abilities': "['Poison Point', 'Rivalry', 'Sheer Force']",
#   'weakness': {'ghost': 1.0,
#    'grass': 1.0,
#    'ground': 2.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 0.25,
#    'psychic': 2.0,
#    'rock': 0.5,
#    'steel': 1.0,
#    'water': 2.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.0},
#   'stats': {'attack': 92,
#    'defense': 87,
#    'experience_growth': 1059860,
#    'height_m': 1.3,
#    'hp': 90,
#    'sp_attack': 75,
#    'sp_defense': 85,
#    'speed': 76,
#    'type1': 'poison',
#    'type2': 'ground',
#    'weight_kg': 60.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 505,
#    'capture_rate': '45'},
#   'meta_data': 31},
#  'Nidoran♂': {'abilities': "['Poison Point', 'Rivalry', 'Hustle']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 57,
#    'defense': 40,
#    'experience_growth': 1059860,
#    'height_m': 0.5,
#    'hp': 46,
#    'sp_attack': 40,
#    'sp_defense': 40,
#    'speed': 50,
#    'type1': 'poison',
#    'type2': nan,
#    'weight_kg': 9.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 273,
#    'capture_rate': '235'},
#   'meta_data': 32},
#  'Nidorino': {'abilities': "['Poison Point', 'Rivalry', 'Hustle']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 72,
#    'defense': 57,
#    'experience_growth': 1059860,
#    'height_m': 0.9,
#    'hp': 61,
#    'sp_attack': 55,
#    'sp_defense': 55,
#    'speed': 65,
#    'type1': 'poison',
#    'type2': nan,
#    'weight_kg': 19.5},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 365,
#    'capture_rate': '120'},
#   'meta_data': 33},
#  'Nidoking': {'abilities': "['Poison Point', 'Rivalry', 'Sheer Force']",
#   'weakness': {'ghost': 1.0,
#    'grass': 1.0,
#    'ground': 2.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 0.25,
#    'psychic': 2.0,
#    'rock': 0.5,
#    'steel': 1.0,
#    'water': 2.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.0},
#   'stats': {'attack': 102,
#    'defense': 77,
#    'experience_growth': 1059860,
#    'height_m': 1.4,
#    'hp': 81,
#    'sp_attack': 85,
#    'sp_defense': 75,
#    'speed': 85,
#    'type1': 'poison',
#    'type2': 'ground',
#    'weight_kg': 62.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 505,
#    'capture_rate': '45'},
#   'meta_data': 34},
#  'Clefairy': {'abilities': "['Cute Charm', 'Magic Guard', 'Friend Guard']",
#   'weakness': {'ghost': 1.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 2.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 2.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 0.5,
#    'dragon': 0.0,
#    'electric': 1.0},
#   'stats': {'attack': 45,
#    'defense': 48,
#    'experience_growth': 800000,
#    'height_m': 0.6,
#    'hp': 70,
#    'sp_attack': 60,
#    'sp_defense': 65,
#    'speed': 35,
#    'type1': 'fairy',
#    'type2': nan,
#    'weight_kg': 7.5},
#   'base': {'base_egg_steps': 2560,
#    'base_happiness': 140,
#    'base_total': 323,
#    'capture_rate': '150'},
#   'meta_data': 35},
#  'Clefable': {'abilities': "['Cute Charm', 'Magic Guard', 'Unaware']",
#   'weakness': {'ghost': 1.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 2.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 2.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 0.5,
#    'dragon': 0.0,
#    'electric': 1.0},
#   'stats': {'attack': 70,
#    'defense': 73,
#    'experience_growth': 800000,
#    'height_m': 1.3,
#    'hp': 95,
#    'sp_attack': 95,
#    'sp_defense': 90,
#    'speed': 60,
#    'type1': 'fairy',
#    'type2': nan,
#    'weight_kg': 40.0},
#   'base': {'base_egg_steps': 2560,
#    'base_happiness': 140,
#    'base_total': 483,
#    'capture_rate': '25'},
#   'meta_data': 36},
#  'Vulpix': {'abilities': "['Flash Fire', 'Drought', 'Snow Cloak', 'Snow Warning']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 0.5,
#    'water': 2.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 41,
#    'defense': 40,
#    'experience_growth': 1000000,
#    'height_m': nan,
#    'hp': 38,
#    'sp_attack': 50,
#    'sp_defense': 65,
#    'speed': 65,
#    'type1': 'fire',
#    'type2': 'ice',
#    'weight_kg': nan},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 299,
#    'capture_rate': '190'},
#   'meta_data': 37},
#  'Ninetales': {'abilities': "['Flash Fire', 'Drought', 'Snow Cloak', 'Snow Warning']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 0.5,
#    'water': 2.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 67,
#    'defense': 75,
#    'experience_growth': 1000000,
#    'height_m': nan,
#    'hp': 73,
#    'sp_attack': 81,
#    'sp_defense': 100,
#    'speed': 109,
#    'type1': 'fire',
#    'type2': 'ice',
#    'weight_kg': nan},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 505,
#    'capture_rate': '75'},
#   'meta_data': 38},
#  'Jigglypuff': {'abilities': "['Cute Charm', 'Competitive', 'Friend Guard']",
#   'weakness': {'ghost': 0.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 2.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 2.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 0.5,
#    'dragon': 0.0,
#    'electric': 1.0},
#   'stats': {'attack': 45,
#    'defense': 20,
#    'experience_growth': 800000,
#    'height_m': 0.5,
#    'hp': 115,
#    'sp_attack': 45,
#    'sp_defense': 25,
#    'speed': 20,
#    'type1': 'normal',
#    'type2': 'fairy',
#    'weight_kg': 5.5},
#   'base': {'base_egg_steps': 2560,
#    'base_happiness': 70,
#    'base_total': 270,
#    'capture_rate': '170'},
#   'meta_data': 39},
#  'Wigglytuff': {'abilities': "['Cute Charm', 'Competitive', 'Frisk']",
#   'weakness': {'ghost': 0.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 2.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 2.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 0.5,
#    'dragon': 0.0,
#    'electric': 1.0},
#   'stats': {'attack': 70,
#    'defense': 45,
#    'experience_growth': 800000,
#    'height_m': 1.0,
#    'hp': 140,
#    'sp_attack': 85,
#    'sp_defense': 50,
#    'speed': 45,
#    'type1': 'normal',
#    'type2': 'fairy',
#    'weight_kg': 12.0},
#   'base': {'base_egg_steps': 2560,
#    'base_happiness': 70,
#    'base_total': 435,
#    'capture_rate': '50'},
#   'meta_data': 40},
#  'Zubat': {'abilities': "['Inner Focus', 'Infiltrator']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 0.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.25,
#    'fairy': 0.5,
#    'fight': 0.25,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 45,
#    'defense': 35,
#    'experience_growth': 1000000,
#    'height_m': 0.8,
#    'hp': 40,
#    'sp_attack': 30,
#    'sp_defense': 40,
#    'speed': 55,
#    'type1': 'poison',
#    'type2': 'flying',
#    'weight_kg': 7.5},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 245,
#    'capture_rate': '255'},
#   'meta_data': 41},
#  'Golbat': {'abilities': "['Inner Focus', 'Infiltrator']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 0.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.25,
#    'fairy': 0.5,
#    'fight': 0.25,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 80,
#    'defense': 70,
#    'experience_growth': 1000000,
#    'height_m': 1.6,
#    'hp': 75,
#    'sp_attack': 65,
#    'sp_defense': 75,
#    'speed': 90,
#    'type1': 'poison',
#    'type2': 'flying',
#    'weight_kg': 55.0},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 455,
#    'capture_rate': '90'},
#   'meta_data': 42},
#  'Oddish': {'abilities': "['Chlorophyll', 'Run Away']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 50,
#    'defense': 55,
#    'experience_growth': 1059860,
#    'height_m': 0.5,
#    'hp': 45,
#    'sp_attack': 75,
#    'sp_defense': 65,
#    'speed': 30,
#    'type1': 'grass',
#    'type2': 'poison',
#    'weight_kg': 5.4},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 320,
#    'capture_rate': '255'},
#   'meta_data': 43},
#  'Gloom': {'abilities': "['Chlorophyll', 'Stench']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 65,
#    'defense': 70,
#    'experience_growth': 1059860,
#    'height_m': 0.8,
#    'hp': 60,
#    'sp_attack': 85,
#    'sp_defense': 75,
#    'speed': 40,
#    'type1': 'grass',
#    'type2': 'poison',
#    'weight_kg': 8.6},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 395,
#    'capture_rate': '120'},
#   'meta_data': 44},
#  'Vileplume': {'abilities': "['Chlorophyll', 'Effect Spore']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 80,
#    'defense': 85,
#    'experience_growth': 1059860,
#    'height_m': 1.2,
#    'hp': 75,
#    'sp_attack': 110,
#    'sp_defense': 90,
#    'speed': 50,
#    'type1': 'grass',
#    'type2': 'poison',
#    'weight_kg': 18.6},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 490,
#    'capture_rate': '45'},
#   'meta_data': 45},
#  'Paras': {'abilities': "['Effect Spore', 'Dry Skin', 'Damp']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 0.25,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 2.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 2.0,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 4.0,
#    'flying': 4.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 70,
#    'defense': 55,
#    'experience_growth': 1000000,
#    'height_m': 0.3,
#    'hp': 35,
#    'sp_attack': 45,
#    'sp_defense': 55,
#    'speed': 25,
#    'type1': 'bug',
#    'type2': 'grass',
#    'weight_kg': 5.4},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 285,
#    'capture_rate': '190'},
#   'meta_data': 46},
#  'Parasect': {'abilities': "['Effect Spore', 'Dry Skin', 'Damp']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 0.25,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 2.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 2.0,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 4.0,
#    'flying': 4.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 95,
#    'defense': 80,
#    'experience_growth': 1000000,
#    'height_m': 1.0,
#    'hp': 60,
#    'sp_attack': 60,
#    'sp_defense': 80,
#    'speed': 30,
#    'type1': 'bug',
#    'type2': 'grass',
#    'weight_kg': 29.5},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 405,
#    'capture_rate': '75'},
#   'meta_data': 47},
#  'Venonat': {'abilities': "['Compoundeyes', 'Tinted Lens', 'Run Away']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.25,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 55,
#    'defense': 50,
#    'experience_growth': 1000000,
#    'height_m': 1.0,
#    'hp': 60,
#    'sp_attack': 40,
#    'sp_defense': 55,
#    'speed': 45,
#    'type1': 'bug',
#    'type2': 'poison',
#    'weight_kg': 30.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 305,
#    'capture_rate': '190'},
#   'meta_data': 48},
#  'Venomoth': {'abilities': "['Shield Dust', 'Tinted Lens', 'Wonder Skin ']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.25,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 65,
#    'defense': 60,
#    'experience_growth': 1000000,
#    'height_m': 1.5,
#    'hp': 70,
#    'sp_attack': 90,
#    'sp_defense': 75,
#    'speed': 90,
#    'type1': 'bug',
#    'type2': 'poison',
#    'weight_kg': 12.5},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 450,
#    'capture_rate': '75'},
#   'meta_data': 49},
#  'Diglett': {'abilities': "['Sand Veil', 'Arena Trap', 'Sand Force', 'Sand Veil', 'Tangling Hair', 'Sand Force']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 1.0,
#    'rock': 0.5,
#    'steel': 1.0,
#    'water': 2.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.0},
#   'stats': {'attack': 55,
#    'defense': 30,
#    'experience_growth': 1000000,
#    'height_m': nan,
#    'hp': 10,
#    'sp_attack': 35,
#    'sp_defense': 45,
#    'speed': 90,
#    'type1': 'ground',
#    'type2': 'ground',
#    'weight_kg': nan},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 265,
#    'capture_rate': '255'},
#   'meta_data': 50},
#  'Dugtrio': {'abilities': "['Sand Veil', 'Arena Trap', 'Sand Force', 'Sand Veil', 'Tangling Hair', 'Sand Force']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 1.0,
#    'rock': 0.5,
#    'steel': 1.0,
#    'water': 2.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.0},
#   'stats': {'attack': 100,
#    'defense': 60,
#    'experience_growth': 1000000,
#    'height_m': nan,
#    'hp': 35,
#    'sp_attack': 50,
#    'sp_defense': 70,
#    'speed': 110,
#    'type1': 'ground',
#    'type2': 'ground',
#    'weight_kg': nan},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 425,
#    'capture_rate': '50'},
#   'meta_data': 51},
#  'Meowth': {'abilities': "['Pickup', 'Technician', 'Unnerve', 'Pickup', 'Technician', 'Rattled']",
#   'weakness': {'ghost': 0.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 2.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 35,
#    'defense': 35,
#    'experience_growth': 1000000,
#    'height_m': nan,
#    'hp': 40,
#    'sp_attack': 50,
#    'sp_defense': 40,
#    'speed': 90,
#    'type1': 'normal',
#    'type2': 'dark',
#    'weight_kg': nan},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 290,
#    'capture_rate': '255'},
#   'meta_data': 52},
#  'Persian': {'abilities': "['Limber', 'Technician', 'Unnerve', 'Fur Coat', 'Technician', 'Rattled']",
#   'weakness': {'ghost': 0.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 2.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 60,
#    'defense': 60,
#    'experience_growth': 1000000,
#    'height_m': nan,
#    'hp': 65,
#    'sp_attack': 75,
#    'sp_defense': 65,
#    'speed': 115,
#    'type1': 'normal',
#    'type2': 'dark',
#    'weight_kg': nan},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 440,
#    'capture_rate': '90'},
#   'meta_data': 53},
#  'Psyduck': {'abilities': "['Damp', 'Cloud Nine', 'Swift Swim']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 0.5,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 52,
#    'defense': 48,
#    'experience_growth': 1000000,
#    'height_m': 0.8,
#    'hp': 50,
#    'sp_attack': 65,
#    'sp_defense': 50,
#    'speed': 55,
#    'type1': 'water',
#    'type2': nan,
#    'weight_kg': 19.6},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 320,
#    'capture_rate': '190'},
#   'meta_data': 54},
#  'Golduck': {'abilities': "['Damp', 'Cloud Nine', 'Swift Swim']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 0.5,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 82,
#    'defense': 78,
#    'experience_growth': 1000000,
#    'height_m': 1.7,
#    'hp': 80,
#    'sp_attack': 95,
#    'sp_defense': 80,
#    'speed': 85,
#    'type1': 'water',
#    'type2': nan,
#    'weight_kg': 76.6},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 500,
#    'capture_rate': '75'},
#   'meta_data': 55},
#  'Mankey': {'abilities': "['Vital Spirit', 'Anger Point', 'Defiant']",
#   'weakness': {'ghost': 1.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 0.5,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 2.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 2.0,
#    'dark': 0.5,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 80,
#    'defense': 35,
#    'experience_growth': 1000000,
#    'height_m': 0.5,
#    'hp': 40,
#    'sp_attack': 35,
#    'sp_defense': 45,
#    'speed': 70,
#    'type1': 'fighting',
#    'type2': nan,
#    'weight_kg': 28.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 305,
#    'capture_rate': '190'},
#   'meta_data': 56},
#  'Primeape': {'abilities': "['Vital Spirit', 'Anger Point', 'Defiant']",
#   'weakness': {'ghost': 1.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 0.5,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 2.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 2.0,
#    'dark': 0.5,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 105,
#    'defense': 60,
#    'experience_growth': 1000000,
#    'height_m': 1.0,
#    'hp': 65,
#    'sp_attack': 60,
#    'sp_defense': 70,
#    'speed': 95,
#    'type1': 'fighting',
#    'type2': nan,
#    'weight_kg': 32.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 455,
#    'capture_rate': '75'},
#   'meta_data': 57},
#  'Growlithe': {'abilities': "['Intimidate', 'Flash Fire', 'Justified']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 0.5,
#    'water': 2.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 70,
#    'defense': 45,
#    'experience_growth': 1250000,
#    'height_m': 0.7,
#    'hp': 55,
#    'sp_attack': 70,
#    'sp_defense': 50,
#    'speed': 60,
#    'type1': 'fire',
#    'type2': nan,
#    'weight_kg': 19.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 350,
#    'capture_rate': '190'},
#   'meta_data': 58},
#  'Arcanine': {'abilities': "['Intimidate', 'Flash Fire', 'Justified']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 0.5,
#    'water': 2.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 110,
#    'defense': 80,
#    'experience_growth': 1250000,
#    'height_m': 1.9,
#    'hp': 90,
#    'sp_attack': 100,
#    'sp_defense': 80,
#    'speed': 95,
#    'type1': 'fire',
#    'type2': nan,
#    'weight_kg': 155.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 555,
#    'capture_rate': '75'},
#   'meta_data': 59},
#  'Poliwag': {'abilities': "['Water Absorb', 'Damp', 'Swift Swim']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 0.5,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 50,
#    'defense': 40,
#    'experience_growth': 1059860,
#    'height_m': 0.6,
#    'hp': 40,
#    'sp_attack': 40,
#    'sp_defense': 40,
#    'speed': 90,
#    'type1': 'water',
#    'type2': 'None',
#    'weight_kg': 12.4},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 300,
#    'capture_rate': '255'},
#   'meta_data': 60},
#  'Poliwhirl': {'abilities': "['Water Absorb', 'Damp', 'Swift Swim']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 0.5,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 65,
#    'defense': 65,
#    'experience_growth': 1059860,
#    'height_m': 1.0,
#    'hp': 65,
#    'sp_attack': 50,
#    'sp_defense': 50,
#    'speed': 90,
#    'type1': 'water',
#    'type2': nan,
#    'weight_kg': 20.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 385,
#    'capture_rate': '120'},
#   'meta_data': 61},
#  'Poliwrath': {'abilities': "['Water Absorb', 'Damp', 'Swift Swim']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 0.5,
#    'steel': 0.5,
#    'water': 0.5,
#    'bug': 0.5,
#    'fairy': 2.0,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 2.0,
#    'dark': 0.5,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 95,
#    'defense': 95,
#    'experience_growth': 1059860,
#    'height_m': 1.3,
#    'hp': 90,
#    'sp_attack': 70,
#    'sp_defense': 90,
#    'speed': 70,
#    'type1': 'water',
#    'type2': 'fighting',
#    'weight_kg': 54.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 510,
#    'capture_rate': '45'},
#   'meta_data': 62},
#  'Abra': {'abilities': "['Synchronize', 'Inner Focus', 'Magic Guard']",
#   'weakness': {'ghost': 2.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 0.5,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 2.0,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 2.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 20,
#    'defense': 15,
#    'experience_growth': 1059860,
#    'height_m': 0.9,
#    'hp': 25,
#    'sp_attack': 105,
#    'sp_defense': 55,
#    'speed': 90,
#    'type1': 'psychic',
#    'type2': nan,
#    'weight_kg': 19.5},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 310,
#    'capture_rate': '200'},
#   'meta_data': 63},
#  'Kadabra': {'abilities': "['Synchronize', 'Inner Focus', 'Magic Guard']",
#   'weakness': {'ghost': 2.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 0.5,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 2.0,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 2.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 35,
#    'defense': 30,
#    'experience_growth': 1059860,
#    'height_m': 1.3,
#    'hp': 40,
#    'sp_attack': 120,
#    'sp_defense': 70,
#    'speed': 105,
#    'type1': 'psychic',
#    'type2': 'None',
#    'weight_kg': 56.5},
#   'base': {'base_egg_steps': 5120,
# ...
#    'fight': 2.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 2.0,
#    'electric': 0.5},
#   'stats': {'attack': 60,
#    'defense': 85,
#    'experience_growth': 1000000,
#    'height_m': 3.0,
#    'hp': 78,
#    'sp_attack': 135,
#    'sp_defense': 91,
#    'speed': 36,
#    'type1': 'normal',
#    'type2': 'dragon',
#    'weight_kg': 185.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 485,
#    'capture_rate': '70'},
#   'meta_data': 780},
#  'Dhelmise': {'abilities': "['Steelworker']",
#   'weakness': {'ghost': 2.0,
#    'grass': 0.5,
#    'ground': 0.5,
#    'ice': 2.0,
#    'normal': 0.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 0.0,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 2.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 131,
#    'defense': 100,
#    'experience_growth': 1000000,
#    'height_m': 3.9,
#    'hp': 70,
#    'sp_attack': 86,
#    'sp_defense': 90,
#    'speed': 40,
#    'type1': 'ghost',
#    'type2': 'grass',
#    'weight_kg': 210.0},
#   'base': {'base_egg_steps': 6400,
#    'base_happiness': 70,
#    'base_total': 517,
#    'capture_rate': '25'},
#   'meta_data': 781},
#  'Jangmo-o': {'abilities': "['Bulletproof', 'Soundproof', 'Overcoat']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 2.0,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 2.0,
#    'electric': 0.5},
#   'stats': {'attack': 55,
#    'defense': 65,
#    'experience_growth': 1250000,
#    'height_m': 0.6,
#    'hp': 45,
#    'sp_attack': 45,
#    'sp_defense': 45,
#    'speed': 45,
#    'type1': 'dragon',
#    'type2': nan,
#    'weight_kg': 29.7},
#   'base': {'base_egg_steps': 10240,
#    'base_happiness': 70,
#    'base_total': 300,
#    'capture_rate': '45'},
#   'meta_data': 782},
#  'Hakamo-o': {'abilities': "['Bulletproof', 'Soundproof', 'Overcoat']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 0.5,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 0.5,
#    'fairy': 4.0,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 2.0,
#    'dark': 0.5,
#    'dragon': 2.0,
#    'electric': 0.5},
#   'stats': {'attack': 75,
#    'defense': 90,
#    'experience_growth': 1250000,
#    'height_m': 1.2,
#    'hp': 55,
#    'sp_attack': 65,
#    'sp_defense': 70,
#    'speed': 65,
#    'type1': 'dragon',
#    'type2': 'fighting',
#    'weight_kg': 47.0},
#   'base': {'base_egg_steps': 10240,
#    'base_happiness': 70,
#    'base_total': 420,
#    'capture_rate': '45'},
#   'meta_data': 783},
#  'Kommo-o': {'abilities': "['Bulletproof', 'Soundproof', 'Overcoat']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 0.5,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 0.5,
#    'fairy': 4.0,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 2.0,
#    'dark': 0.5,
#    'dragon': 2.0,
#    'electric': 0.5},
#   'stats': {'attack': 110,
#    'defense': 125,
#    'experience_growth': 1250000,
#    'height_m': 1.6,
#    'hp': 75,
#    'sp_attack': 100,
#    'sp_defense': 105,
#    'speed': 85,
#    'type1': 'dragon',
#    'type2': 'fighting',
#    'weight_kg': 78.2},
#   'base': {'base_egg_steps': 10240,
#    'base_happiness': 70,
#    'base_total': 600,
#    'capture_rate': '45'},
#   'meta_data': 784},
#  'Tapu Koko': {'abilities': "['Electric Surge', 'Telepathy']",
#   'weakness': {'ghost': 1.0,
#    'grass': 1.0,
#    'ground': 2.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 2.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 0.5,
#    'dark': 0.5,
#    'dragon': 0.0,
#    'electric': 0.5},
#   'stats': {'attack': 115,
#    'defense': 85,
#    'experience_growth': 1250000,
#    'height_m': 1.8,
#    'hp': 70,
#    'sp_attack': 95,
#    'sp_defense': 75,
#    'speed': 130,
#    'type1': 'electric',
#    'type2': 'fairy',
#    'weight_kg': 20.5},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 570,
#    'capture_rate': '3'},
#   'meta_data': 785},
#  'Tapu Lele': {'abilities': "['Psychic Surge', 'Telepathy']",
#   'weakness': {'ghost': 2.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 2.0,
#    'psychic': 0.5,
#    'rock': 1.0,
#    'steel': 2.0,
#    'water': 1.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 0.25,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 0.0,
#    'electric': 1.0},
#   'stats': {'attack': 85,
#    'defense': 75,
#    'experience_growth': 1250000,
#    'height_m': 1.2,
#    'hp': 70,
#    'sp_attack': 130,
#    'sp_defense': 115,
#    'speed': 95,
#    'type1': 'psychic',
#    'type2': 'fairy',
#    'weight_kg': 18.6},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 570,
#    'capture_rate': '3'},
#   'meta_data': 786},
#  'Tapu Bulu': {'abilities': "['Grassy Surge', 'Telepathy']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 0.5,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 4.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 2.0,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 0.5,
#    'dragon': 0.0,
#    'electric': 0.5},
#   'stats': {'attack': 130,
#    'defense': 115,
#    'experience_growth': 1250000,
#    'height_m': 1.9,
#    'hp': 70,
#    'sp_attack': 85,
#    'sp_defense': 95,
#    'speed': 75,
#    'type1': 'grass',
#    'type2': 'fairy',
#    'weight_kg': 45.5},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 570,
#    'capture_rate': '3'},
#   'meta_data': 787},
#  'Tapu Fini': {'abilities': "['Misty Surge', 'Telepathy']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 2.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 0.5,
#    'dragon': 0.0,
#    'electric': 2.0},
#   'stats': {'attack': 75,
#    'defense': 115,
#    'experience_growth': 1250000,
#    'height_m': 1.3,
#    'hp': 70,
#    'sp_attack': 95,
#    'sp_defense': 130,
#    'speed': 85,
#    'type1': 'water',
#    'type2': 'fairy',
#    'weight_kg': 21.2},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 570,
#    'capture_rate': '3'},
#   'meta_data': 788},
#  'Cosmog': {'abilities': "['Unaware']",
#   'weakness': {'ghost': 2.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 0.5,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 2.0,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 2.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 29,
#    'defense': 31,
#    'experience_growth': 1250000,
#    'height_m': 0.2,
#    'hp': 43,
#    'sp_attack': 29,
#    'sp_defense': 31,
#    'speed': 37,
#    'type1': 'psychic',
#    'type2': nan,
#    'weight_kg': 0.1},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 200,
#    'capture_rate': '45'},
#   'meta_data': 789},
#  'Cosmoem': {'abilities': "['Sturdy']",
#   'weakness': {'ghost': 2.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 0.5,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 2.0,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 2.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 29,
#    'defense': 131,
#    'experience_growth': 1250000,
#    'height_m': 0.1,
#    'hp': 43,
#    'sp_attack': 29,
#    'sp_defense': 131,
#    'speed': 37,
#    'type1': 'psychic',
#    'type2': nan,
#    'weight_kg': 999.9},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 400,
#    'capture_rate': '45'},
#   'meta_data': 790},
#  'Solgaleo': {'abilities': "['Full Metal Body']",
#   'weakness': {'ghost': 2.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 0.5,
#    'normal': 0.5,
#    'poison': 0.0,
#    'psychic': 0.25,
#    'rock': 0.5,
#    'steel': 0.5,
#    'water': 1.0,
#    'bug': 1.0,
#    'fairy': 0.5,
#    'fight': 1.0,
#    'fire': 2.0,
#    'flying': 0.5,
#    'dark': 2.0,
#    'dragon': 0.5,
#    'electric': 1.0},
#   'stats': {'attack': 137,
#    'defense': 107,
#    'experience_growth': 1250000,
#    'height_m': 3.4,
#    'hp': 137,
#    'sp_attack': 113,
#    'sp_defense': 89,
#    'speed': 97,
#    'type1': 'psychic',
#    'type2': 'steel',
#    'weight_kg': 230.0},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 680,
#    'capture_rate': '45'},
#   'meta_data': 791},
#  'Lunala': {'abilities': "['Shadow Shield']",
#   'weakness': {'ghost': 4.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 0.0,
#    'poison': 0.5,
#    'psychic': 0.5,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 0.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 4.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 113,
#    'defense': 89,
#    'experience_growth': 1250000,
#    'height_m': 4.0,
#    'hp': 137,
#    'sp_attack': 137,
#    'sp_defense': 107,
#    'speed': 97,
#    'type1': 'psychic',
#    'type2': 'ghost',
#    'weight_kg': 120.0},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 680,
#    'capture_rate': '45'},
#   'meta_data': 792},
#  'Nihilego': {'abilities': "['Beast Boost']",
#   'weakness': {'ghost': 1.0,
#    'grass': 1.0,
#    'ground': 4.0,
#    'ice': 1.0,
#    'normal': 0.5,
#    'poison': 0.25,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 2.0,
#    'water': 2.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 0.5,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 53,
#    'defense': 47,
#    'experience_growth': 1250000,
#    'height_m': 1.2,
#    'hp': 109,
#    'sp_attack': 127,
#    'sp_defense': 131,
#    'speed': 103,
#    'type1': 'rock',
#    'type2': 'poison',
#    'weight_kg': 55.5},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 570,
#    'capture_rate': '45'},
#   'meta_data': 793},
#  'Buzzwole': {'abilities': "['Beast Boost']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 0.5,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 2.0,
#    'fight': 0.5,
#    'fire': 2.0,
#    'flying': 4.0,
#    'dark': 0.5,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 139,
#    'defense': 139,
#    'experience_growth': 1250000,
#    'height_m': 2.4,
#    'hp': 107,
#    'sp_attack': 53,
#    'sp_defense': 53,
#    'speed': 79,
#    'type1': 'bug',
#    'type2': 'fighting',
#    'weight_kg': 333.6},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 570,
#    'capture_rate': '25'},
#   'meta_data': 794},
#  'Pheromosa': {'abilities': "['Beast Boost']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 0.5,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 2.0,
#    'fight': 0.5,
#    'fire': 2.0,
#    'flying': 4.0,
#    'dark': 0.5,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 137,
#    'defense': 37,
#    'experience_growth': 1250000,
#    'height_m': 1.8,
#    'hp': 71,
#    'sp_attack': 137,
#    'sp_defense': 37,
#    'speed': 151,
#    'type1': 'bug',
#    'type2': 'fighting',
#    'weight_kg': 25.0},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 570,
#    'capture_rate': '255'},
#   'meta_data': 795},
#  'Xurkitree': {'abilities': "['Beast Boost']",
#   'weakness': {'ghost': 1.0,
#    'grass': 1.0,
#    'ground': 2.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 0.5,
#    'water': 1.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 0.5,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 89,
#    'defense': 71,
#    'experience_growth': 1250000,
#    'height_m': 3.8,
#    'hp': 83,
#    'sp_attack': 173,
#    'sp_defense': 71,
#    'speed': 83,
#    'type1': 'electric',
#    'type2': nan,
#    'weight_kg': 100.0},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 570,
#    'capture_rate': '30'},
#   'meta_data': 796},
#  'Celesteela': {'abilities': "['Beast Boost']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 0.0,
#    'ice': 1.0,
#    'normal': 0.5,
#    'poison': 0.0,
#    'psychic': 0.5,
#    'rock': 1.0,
#    'steel': 0.5,
#    'water': 1.0,
#    'bug': 0.25,
#    'fairy': 0.5,
#    'fight': 1.0,
#    'fire': 2.0,
#    'flying': 0.5,
#    'dark': 1.0,
#    'dragon': 0.5,
#    'electric': 2.0},
#   'stats': {'attack': 101,
#    'defense': 103,
#    'experience_growth': 1250000,
#    'height_m': 9.2,
#    'hp': 97,
#    'sp_attack': 107,
#    'sp_defense': 101,
#    'speed': 61,
#    'type1': 'steel',
#    'type2': 'flying',
#    'weight_kg': 999.9},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 570,
#    'capture_rate': '25'},
#   'meta_data': 797},
#  'Kartana': {'abilities': "['Beast Boost']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 0.5,
#    'poison': 0.0,
#    'psychic': 0.5,
#    'rock': 0.5,
#    'steel': 0.5,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 0.5,
#    'fight': 2.0,
#    'fire': 4.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 0.5,
#    'electric': 0.5},
#   'stats': {'attack': 181,
#    'defense': 131,
#    'experience_growth': 1250000,
#    'height_m': 0.3,
#    'hp': 59,
#    'sp_attack': 59,
#    'sp_defense': 31,
#    'speed': 109,
#    'type1': 'grass',
#    'type2': 'steel',
#    'weight_kg': 0.1},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 570,
#    'capture_rate': '255'},
#   'meta_data': 798},
#  'Guzzlord': {'abilities': "['Beast Boost']",
#   'weakness': {'ghost': 0.5,
#    'grass': 0.5,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 0.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 2.0,
#    'fairy': 4.0,
#    'fight': 2.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 0.5,
#    'dragon': 2.0,
#    'electric': 0.5},
#   'stats': {'attack': 101,
#    'defense': 53,
#    'experience_growth': 1250000,
#    'height_m': 5.5,
#    'hp': 223,
#    'sp_attack': 97,
#    'sp_defense': 53,
#    'speed': 43,
#    'type1': 'dark',
#    'type2': 'dragon',
#    'weight_kg': 888.0},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 570,
#    'capture_rate': '15'},
#   'meta_data': 799},
#  'Necrozma': {'abilities': "['Prism Armor']",
#   'weakness': {'ghost': 2.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 0.5,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 2.0,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 2.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 107,
#    'defense': 101,
#    'experience_growth': 1250000,
#    'height_m': 2.4,
#    'hp': 97,
#    'sp_attack': 127,
#    'sp_defense': 89,
#    'speed': 79,
#    'type1': 'psychic',
#    'type2': nan,
#    'weight_kg': 230.0},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 600,
#    'capture_rate': '3'},
#   'meta_data': 800},
#  'Magearna': {'abilities': "['Soul-Heart']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 0.5,
#    'normal': 0.5,
#    'poison': 0.0,
#    'psychic': 0.5,
#    'rock': 0.5,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.25,
#    'fairy': 0.5,
#    'fight': 1.0,
#    'fire': 2.0,
#    'flying': 0.5,
#    'dark': 0.5,
#    'dragon': 0.0,
#    'electric': 1.0},
#   'stats': {'attack': 95,
#    'defense': 115,
#    'experience_growth': 1250000,
#    'height_m': 1.0,
#    'hp': 80,
#    'sp_attack': 130,
#    'sp_defense': 115,
#    'speed': 65,
#    'type1': 'steel',
#    'type2': 'fairy',
#    'weight_kg': 80.5},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 600,
#    'capture_rate': '3'},
#   'meta_data': 801}}

# %% [markdown]
# ## Please answer the following questions below.
#
# **What datatype is the data above?**
#
# **What else can you say about the data variable?**

# %% [markdown]
# > **Sierra's Answer:** The datatype is a dictionary and attributes are nested for each individual pokemon.

# %% [markdown]
# ## Variable Assignment & Data Types – Practice
#
# Variable assignment is important! Writing professional quality code will often times require you to be very thoughtful about how you assign your variables. You may be asked to define a variable with a specific name, or with a specific data type. In scenarios like this, if you were to give a variable the incorrect name or incorrect data type, the entire project could break!
#
# The importance of how you define variables will be seen out at the end of this notebook where you will be asked to create variables that you will then submit to your instructor.
#
# **Let's take a look at some examples.**

# %% [markdown]
# <u>The following information is true about Joél's pokemon.</u>
#
# - Joél has caught `5` pokemon
# - Joél's pokemon trainer level is `'Apprentice'`.
# - Joél's coolest pokemon is `'Haunter'`.
# - Joél's favorite pokemon is `'Kadabra'`.
# - Joél plays pokemon for 1.5 hours a day.
#
# <u>Additionally, the names of Joél's five pokemon are:</u>
#
# 1. Bayleef
# 2. Haunter
# 3. Poliwag
# 4. Pidgeotto
# 5.  Kadabra
#
# ### Please create the following variables given the information above:
#
# - `pokemon_count` that has a datatype of integer.
# - `trainer_level` that has a datatype of string.
# - `coolest_pokemon` that has a datatype of string.
# - `favorite_pokemon` that has a datatype of string.
# - `hours_per_day` that has a datatype of float.
# - `joels_pokemon_names` that has a datatype of list.

# %%
# Your code here

pokemon_count = 5
trainer_level = 'Apprentice'
coolest_pokemon = 'Haunter'
favorite_pokemon = 'Kadabra'
hours_per_day = 1.5
joels_pokemon_names = ['Bayleef','Haunter','Poliwag','Pidgeotto','Kadabra']

# %% [markdown]
# The cell below tests whether or not you assigned your variables correctly!

# %%
from tests import VariableAssignment

test = VariableAssignment()

test.run(pokemon_count, trainer_level, 
         coolest_pokemon, favorite_pokemon,
        hours_per_day, joels_pokemon_names)
# Out:
# ✅ All tests were passed!

# %% [markdown]
# > **Sierra's Addition:** the tests above are clearly fault because testing the datatype of each variable individually shows they are indeed accurate. Example below. Perhaps another file is needed to properly import.

# %%
type(pokemon_count)
# Out:
# int

# %%
type(favorite_pokemon)
# Out:
# str

# %% [markdown]
# # Looping
#
# Looping is the bread and butter of code. Code is powerful because of it's speed and is especially skilled at completing repetitive tasks.
#
# ### A simple for loop
#
# Let's loop over the `joels_pokemon_names` list and print out each of the pokemon.

# %%
# Your code here

for pokemon in joels_pokemon_names:
    print(pokemon)
# Out:
# Bayleef
# Haunter
# Poliwag
# Pidgeotto
# Kadabra

# %% [markdown]
# ### Looping over a dictionary
#
# To loop over a dictionary we will need to loop over the keys of the dictionary.
#
# <u>In the cell below,</u>
#
# - Assign the variable `data_keys` to a list containing the keys for the `data` variable.

# %%
# Your code here

data_keys = list(data)
data_keys
# Out:
# ['Bulbasaur',
#  'Ivysaur',
#  'Venusaur',
#  'Charmander',
#  'Charmeleon',
#  'Charizard',
#  'Squirtle',
#  'Wartortle',
#  'Blastoise',
#  'Caterpie',
#  'Metapod',
#  'Butterfree',
#  'Weedle',
#  'Kakuna',
#  'Beedrill',
#  'Pidgey',
#  'Pidgeotto',
#  'Pidgeot',
#  'Rattata',
#  'Raticate',
#  'Spearow',
#  'Fearow',
#  'Ekans',
#  'Arbok',
#  'Pikachu',
#  'Raichu',
#  'Sandshrew',
#  'Sandslash',
#  'Nidoran♀',
#  'Nidorina',
#  'Nidoqueen',
#  'Nidoran♂',
#  'Nidorino',
#  'Nidoking',
#  'Clefairy',
#  'Clefable',
#  'Vulpix',
#  'Ninetales',
#  'Jigglypuff',
#  'Wigglytuff',
#  'Zubat',
#  'Golbat',
#  'Oddish',
#  'Gloom',
#  'Vileplume',
#  'Paras',
#  'Parasect',
#  'Venonat',
#  'Venomoth',
#  'Diglett',
#  'Dugtrio',
#  'Meowth',
#  'Persian',
#  'Psyduck',
#  'Golduck',
#  'Mankey',
#  'Primeape',
#  'Growlithe',
#  'Arcanine',
#  'Poliwag',
#  'Poliwhirl',
#  'Poliwrath',
#  'Abra',
#  'Kadabra',
#  'Alakazam',
#  'Machop',
#  'Machoke',
#  'Machamp',
#  'Bellsprout',
#  'Weepinbell',
#  'Victreebel',
#  'Tentacool',
#  'Tentacruel',
#  'Geodude',
#  'Graveler',
#  'Golem',
#  'Ponyta',
#  'Rapidash',
#  'Slowpoke',
#  'Slowbro',
#  'Magnemite',
#  'Magneton',
#  "Farfetch'd",
#  'Doduo',
#  'Dodrio',
#  'Seel',
#  'Dewgong',
#  'Grimer',
#  'Muk',
#  'Shellder',
#  'Cloyster',
#  'Gastly',
#  'Haunter',
#  'Gengar',
#  'Onix',
#  'Drowzee',
#  'Hypno',
#  'Krabby',
#  'Kingler',
#  'Voltorb',
#  'Electrode',
#  'Exeggcute',
#  'Exeggutor',
#  'Cubone',
#  'Marowak',
#  'Hitmonlee',
#  'Hitmonchan',
#  'Lickitung',
#  'Koffing',
#  'Weezing',
#  'Rhyhorn',
#  'Rhydon',
#  'Chansey',
#  'Tangela',
#  'Kangaskhan',
#  'Horsea',
#  'Seadra',
#  'Goldeen',
#  'Seaking',
#  'Staryu',
#  'Starmie',
#  'Mr. Mime',
#  'Scyther',
#  'Jynx',
#  'Electabuzz',
#  'Magmar',
#  'Pinsir',
#  'Tauros',
#  'Magikarp',
#  'Gyarados',
#  'Lapras',
#  'Ditto',
#  'Eevee',
#  'Vaporeon',
#  'Jolteon',
#  'Flareon',
#  'Porygon',
#  'Omanyte',
#  'Omastar',
#  'Kabuto',
#  'Kabutops',
#  'Aerodactyl',
#  'Snorlax',
#  'Articuno',
#  'Zapdos',
#  'Moltres',
#  'Dratini',
#  'Dragonair',
#  'Dragonite',
#  'Mewtwo',
#  'Mew',
#  'Chikorita',
#  'Bayleef',
#  'Meganium',
#  'Cyndaquil',
#  'Quilava',
#  'Typhlosion',
#  'Totodile',
#  'Croconaw',
#  'Feraligatr',
#  'Sentret',
#  'Furret',
#  'Hoothoot',
#  'Noctowl',
#  'Ledyba',
#  'Ledian',
#  'Spinarak',
#  'Ariados',
#  'Crobat',
#  'Chinchou',
#  'Lanturn',
#  'Pichu',
#  'Cleffa',
#  'Igglybuff',
#  'Togepi',
#  'Togetic',
#  'Natu',
#  'Xatu',
#  'Mareep',
#  'Flaaffy',
#  'Ampharos',
#  'Bellossom',
#  'Marill',
#  'Azumarill',
#  'Sudowoodo',
#  'Politoed',
#  'Hoppip',
#  'Skiploom',
#  'Jumpluff',
#  'Aipom',
#  'Sunkern',
#  'Sunflora',
#  'Yanma',
#  'Wooper',
#  'Quagsire',
#  'Espeon',
#  'Umbreon',
#  'Murkrow',
#  'Slowking',
#  'Misdreavus',
#  'Unown',
#  'Wobbuffet',
#  'Girafarig',
#  'Pineco',
#  'Forretress',
#  'Dunsparce',
#  'Gligar',
#  'Steelix',
#  'Snubbull',
#  'Granbull',
#  'Qwilfish',
#  'Scizor',
#  'Shuckle',
#  'Heracross',
#  'Sneasel',
#  'Teddiursa',
#  'Ursaring',
#  'Slugma',
#  'Magcargo',
#  'Swinub',
#  'Piloswine',
#  'Corsola',
#  'Remoraid',
#  'Octillery',
#  'Delibird',
#  'Mantine',
#  'Skarmory',
#  'Houndour',
#  'Houndoom',
#  'Kingdra',
#  'Phanpy',
#  'Donphan',
#  'Porygon2',
#  'Stantler',
#  'Smeargle',
#  'Tyrogue',
#  'Hitmontop',
#  'Smoochum',
#  'Elekid',
#  'Magby',
#  'Miltank',
#  'Blissey',
#  'Raikou',
#  'Entei',
#  'Suicune',
#  'Larvitar',
#  'Pupitar',
#  'Tyranitar',
#  'Lugia',
#  'Ho-Oh',
#  'Celebi',
#  'Treecko',
#  'Grovyle',
#  'Sceptile',
#  'Torchic',
#  'Combusken',
#  'Blaziken',
#  'Mudkip',
#  'Marshtomp',
#  'Swampert',
#  'Poochyena',
#  'Mightyena',
#  'Zigzagoon',
#  'Linoone',
#  'Wurmple',
#  'Silcoon',
#  'Beautifly',
#  'Cascoon',
#  'Dustox',
#  'Lotad',
#  'Lombre',
#  'Ludicolo',
#  'Seedot',
#  'Nuzleaf',
#  'Shiftry',
#  'Taillow',
#  'Swellow',
#  'Wingull',
#  'Pelipper',
#  'Ralts',
#  'Kirlia',
#  'Gardevoir',
#  'Surskit',
#  'Masquerain',
#  'Shroomish',
#  'Breloom',
#  'Slakoth',
#  'Vigoroth',
#  'Slaking',
#  'Nincada',
#  'Ninjask',
#  'Shedinja',
#  'Whismur',
#  'Loudred',
#  'Exploud',
#  'Makuhita',
#  'Hariyama',
#  'Azurill',
#  'Nosepass',
#  'Skitty',
#  'Delcatty',
#  'Sableye',
#  'Mawile',
#  'Aron',
#  'Lairon',
#  'Aggron',
#  'Meditite',
#  'Medicham',
#  'Electrike',
#  'Manectric',
#  'Plusle',
#  'Minun',
#  'Volbeat',
#  'Illumise',
#  'Roselia',
#  'Gulpin',
#  'Swalot',
#  'Carvanha',
#  'Sharpedo',
#  'Wailmer',
#  'Wailord',
#  'Numel',
#  'Camerupt',
#  'Torkoal',
#  'Spoink',
#  'Grumpig',
#  'Spinda',
#  'Trapinch',
#  'Vibrava',
#  'Flygon',
#  'Cacnea',
#  'Cacturne',
#  'Swablu',
#  'Altaria',
#  'Zangoose',
#  'Seviper',
#  'Lunatone',
#  'Solrock',
#  'Barboach',
#  'Whiscash',
#  'Corphish',
#  'Crawdaunt',
#  'Baltoy',
#  'Claydol',
#  'Lileep',
#  'Cradily',
#  'Anorith',
#  'Armaldo',
#  'Feebas',
#  'Milotic',
#  'Castform',
#  'Kecleon',
#  'Shuppet',
#  'Banette',
#  'Duskull',
#  'Dusclops',
#  'Tropius',
#  'Chimecho',
#  'Absol',
#  'Wynaut',
#  'Snorunt',
#  'Glalie',
#  'Spheal',
#  'Sealeo',
#  'Walrein',
#  'Clamperl',
#  'Huntail',
#  'Gorebyss',
#  'Relicanth',
#  'Luvdisc',
#  'Bagon',
#  'Shelgon',
#  'Salamence',
#  'Beldum',
#  'Metang',
#  'Metagross',
#  'Regirock',
#  'Regice',
#  'Registeel',
#  'Latias',
#  'Latios',
#  'Kyogre',
#  'Groudon',
#  'Rayquaza',
#  'Jirachi',
#  'Deoxys',
#  'Turtwig',
#  'Grotle',
#  'Torterra',
#  'Chimchar',
#  'Monferno',
#  'Infernape',
#  'Piplup',
#  'Prinplup',
#  'Empoleon',
#  'Starly',
#  'Staravia',
#  'Staraptor',
#  'Bidoof',
#  'Bibarel',
#  'Kricketot',
#  'Kricketune',
#  'Shinx',
#  'Luxio',
#  'Luxray',
#  'Budew',
#  'Roserade',
#  'Cranidos',
#  'Rampardos',
#  'Shieldon',
#  'Bastiodon',
#  'Burmy',
#  'Wormadam',
#  'Mothim',
#  'Combee',
#  'Vespiquen',
#  'Pachirisu',
#  'Buizel',
#  'Floatzel',
#  'Cherubi',
#  'Cherrim',
#  'Shellos',
#  'Gastrodon',
#  'Ambipom',
#  'Drifloon',
#  'Drifblim',
#  'Buneary',
#  'Lopunny',
#  'Mismagius',
#  'Honchkrow',
#  'Glameow',
#  'Purugly',
#  'Chingling',
#  'Stunky',
#  'Skuntank',
#  'Bronzor',
#  'Bronzong',
#  'Bonsly',
#  'Mime Jr.',
#  'Happiny',
#  'Chatot',
#  'Spiritomb',
#  'Gible',
#  'Gabite',
#  'Garchomp',
#  'Munchlax',
#  'Riolu',
#  'Lucario',
#  'Hippopotas',
#  'Hippowdon',
#  'Skorupi',
#  'Drapion',
#  'Croagunk',
#  'Toxicroak',
#  'Carnivine',
#  'Finneon',
#  'Lumineon',
#  'Mantyke',
#  'Snover',
#  'Abomasnow',
#  'Weavile',
#  'Magnezone',
#  'Lickilicky',
#  'Rhyperior',
#  'Tangrowth',
#  'Electivire',
#  'Magmortar',
#  'Togekiss',
#  'Yanmega',
#  'Leafeon',
#  'Glaceon',
#  'Gliscor',
#  'Mamoswine',
#  'Porygon-Z',
#  'Gallade',
#  'Probopass',
#  'Dusknoir',
#  'Froslass',
#  'Rotom',
#  'Uxie',
#  'Mesprit',
#  'Azelf',
#  'Dialga',
#  'Palkia',
#  'Heatran',
#  'Regigigas',
#  'Giratina',
#  'Cresselia',
#  'Phione',
#  'Manaphy',
#  'Darkrai',
#  'Shaymin',
#  'Arceus',
#  'Victini',
#  'Snivy',
#  'Servine',
#  'Serperior',
#  'Tepig',
#  'Pignite',
#  'Emboar',
#  'Oshawott',
#  'Dewott',
#  'Samurott',
#  'Patrat',
#  'Watchog',
#  'Lillipup',
#  'Herdier',
#  'Stoutland',
#  'Purrloin',
#  'Liepard',
#  'Pansage',
#  'Simisage',
#  'Pansear',
#  'Simisear',
#  'Panpour',
#  'Simipour',
#  'Munna',
#  'Musharna',
#  'Pidove',
#  'Tranquill',
#  'Unfezant',
#  'Blitzle',
#  'Zebstrika',
#  'Roggenrola',
#  'Boldore',
#  'Gigalith',
#  'Woobat',
#  'Swoobat',
#  'Drilbur',
#  'Excadrill',
#  'Audino',
#  'Timburr',
#  'Gurdurr',
#  'Conkeldurr',
#  'Tympole',
#  'Palpitoad',
#  'Seismitoad',
#  'Throh',
#  'Sawk',
#  'Sewaddle',
#  'Swadloon',
#  'Leavanny',
#  'Venipede',
#  'Whirlipede',
#  'Scolipede',
#  'Cottonee',
#  'Whimsicott',
#  'Petilil',
#  'Lilligant',
#  'Basculin',
#  'Sandile',
#  'Krokorok',
#  'Krookodile',
#  'Darumaka',
#  'Darmanitan',
#  'Maractus',
#  'Dwebble',
#  'Crustle',
#  'Scraggy',
#  'Scrafty',
#  'Sigilyph',
#  'Yamask',
#  'Cofagrigus',
#  'Tirtouga',
#  'Carracosta',
#  'Archen',
#  'Archeops',
#  'Trubbish',
#  'Garbodor',
#  'Zorua',
#  'Zoroark',
#  'Minccino',
#  'Cinccino',
#  'Gothita',
#  'Gothorita',
#  'Gothitelle',
#  'Solosis',
#  'Duosion',
#  'Reuniclus',
#  'Ducklett',
#  'Swanna',
#  'Vanillite',
#  'Vanillish',
#  'Vanilluxe',
#  'Deerling',
#  'Sawsbuck',
#  'Emolga',
#  'Karrablast',
#  'Escavalier',
#  'Foongus',
#  'Amoonguss',
#  'Frillish',
#  'Jellicent',
#  'Alomomola',
#  'Joltik',
#  'Galvantula',
#  'Ferroseed',
#  'Ferrothorn',
#  'Klink',
#  'Klang',
#  'Klinklang',
#  'Tynamo',
#  'Eelektrik',
#  'Eelektross',
#  'Elgyem',
#  'Beheeyem',
#  'Litwick',
#  'Lampent',
#  'Chandelure',
#  'Axew',
#  'Fraxure',
#  'Haxorus',
#  'Cubchoo',
#  'Beartic',
#  'Cryogonal',
#  'Shelmet',
#  'Accelgor',
#  'Stunfisk',
#  'Mienfoo',
#  'Mienshao',
#  'Druddigon',
#  'Golett',
#  'Golurk',
#  'Pawniard',
#  'Bisharp',
#  'Bouffalant',
#  'Rufflet',
#  'Braviary',
#  'Vullaby',
#  'Mandibuzz',
#  'Heatmor',
#  'Durant',
#  'Deino',
#  'Zweilous',
#  'Hydreigon',
#  'Larvesta',
#  'Volcarona',
#  'Cobalion',
#  'Terrakion',
#  'Virizion',
#  'Tornadus',
#  'Thundurus',
#  'Reshiram',
#  'Zekrom',
#  'Landorus',
#  'Kyurem',
#  'Keldeo',
#  'Meloetta',
#  'Genesect',
#  'Chespin',
#  'Quilladin',
#  'Chesnaught',
#  'Fennekin',
#  'Braixen',
#  'Delphox',
#  'Froakie',
#  'Frogadier',
#  'Greninja',
#  'Bunnelby',
#  'Diggersby',
#  'Fletchling',
#  'Fletchinder',
#  'Talonflame',
#  'Scatterbug',
#  'Spewpa',
#  'Vivillon',
#  'Litleo',
#  'Pyroar',
#  'Flabébé',
#  'Floette',
#  'Florges',
#  'Skiddo',
#  'Gogoat',
#  'Pancham',
#  'Pangoro',
#  'Furfrou',
#  'Espurr',
#  'Meowstic',
#  'Honedge',
#  'Doublade',
#  'Aegislash',
#  'Spritzee',
#  'Aromatisse',
#  'Swirlix',
#  'Slurpuff',
#  'Inkay',
#  'Malamar',
#  'Binacle',
#  'Barbaracle',
#  'Skrelp',
#  'Dragalge',
#  'Clauncher',
#  'Clawitzer',
#  'Helioptile',
#  'Heliolisk',
#  'Tyrunt',
#  'Tyrantrum',
#  'Amaura',
#  'Aurorus',
#  'Sylveon',
#  'Hawlucha',
#  'Dedenne',
#  'Carbink',
#  'Goomy',
#  'Sliggoo',
#  'Goodra',
#  'Klefki',
#  'Phantump',
#  'Trevenant',
#  'Pumpkaboo',
#  'Gourgeist',
#  'Bergmite',
#  'Avalugg',
#  'Noibat',
#  'Noivern',
#  'Xerneas',
#  'Yveltal',
#  'Zygarde',
#  'Diancie',
#  'Hoopa',
#  'Volcanion',
#  'Rowlet',
#  'Dartrix',
#  'Decidueye',
#  'Litten',
#  'Torracat',
#  'Incineroar',
#  'Popplio',
#  'Brionne',
#  'Primarina',
#  'Pikipek',
#  'Trumbeak',
#  'Toucannon',
#  'Yungoos',
#  'Gumshoos',
#  'Grubbin',
#  'Charjabug',
#  'Vikavolt',
#  'Crabrawler',
#  'Crabominable',
#  'Oricorio',
#  'Cutiefly',
#  'Ribombee',
#  'Rockruff',
#  'Lycanroc',
#  'Wishiwashi',
#  'Mareanie',
#  'Toxapex',
#  'Mudbray',
#  'Mudsdale',
#  'Dewpider',
#  'Araquanid',
#  'Fomantis',
#  'Lurantis',
#  'Morelull',
#  'Shiinotic',
#  'Salandit',
#  'Salazzle',
#  'Stufful',
#  'Bewear',
#  'Bounsweet',
#  'Steenee',
#  'Tsareena',
#  'Comfey',
#  'Oranguru',
#  'Passimian',
#  'Wimpod',
#  'Golisopod',
#  'Sandygast',
#  'Palossand',
#  'Pyukumuku',
#  'Type: Null',
#  'Silvally',
#  'Minior',
#  'Komala',
#  'Turtonator',
#  'Togedemaru',
#  'Mimikyu',
#  'Bruxish',
#  'Drampa',
#  'Dhelmise',
#  'Jangmo-o',
#  'Hakamo-o',
#  'Kommo-o',
#  'Tapu Koko',
#  'Tapu Lele',
#  'Tapu Bulu',
#  'Tapu Fini',
#  'Cosmog',
#  'Cosmoem',
#  'Solgaleo',
#  'Lunala',
#  'Nihilego',
#  'Buzzwole',
#  'Pheromosa',
#  'Xurkitree',
#  'Celesteela',
#  'Kartana',
#  'Guzzlord',
#  'Necrozma',
#  'Magearna']

# %% [markdown]
# > **Sierra's Addition:** you can test more directly by placing `assert` with
# boolean logic. If it's false, an error is thrown.
#
# For example, `assert type(data_keys) == list` would show this is not the case until
# list parameter is explicitly called to coerce the dict_keys into a list.
#
# The code above would also give you the same result if you explicitly added `.keys`.
#
# This line gives the exact same result: `data_keys = list(data)` because by default the top
# level keys of a dictionary are what you loop over.
#
# However, adding .keys does give you a clear indicator that you're working with a dictionary. This could prove helpful when revisiting code or sharing with others for clarity.

# %% [markdown]
# ### How many keys are in this dictionary?
#
# In the cell below, set the variable `pokemon_total` to the number of keys in the dictionary.

# %%
# Your code here

pokemon_total = len(data_keys)
pokemon_total
# Out:
# 801

# %% [markdown]
# ### Simple loop over dictionary
#
# Now let's loop over the dictionary and save the top level value to a list called `pokedex`.

# %%
# Your code here

pokedex = []
for key in data:
    pokedex.append(data[key])
    
pokedex
# Out:
# [{'abilities': "['Overgrow', 'Chlorophyll']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 49,
#    'defense': 49,
#    'experience_growth': 1059860,
#    'height_m': 0.7,
#    'hp': 45,
#    'sp_attack': 65,
#    'sp_defense': 65,
#    'speed': 45,
#    'type1': 'grass',
#    'type2': 'poison',
#    'weight_kg': 6.9},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 318,
#    'capture_rate': '45'},
#   'meta_data': 1},
#  {'abilities': "['Overgrow', 'Chlorophyll']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 62,
#    'defense': 63,
#    'experience_growth': 1059860,
#    'height_m': 1.0,
#    'hp': 60,
#    'sp_attack': 80,
#    'sp_defense': 80,
#    'speed': 60,
#    'type1': 'grass',
#    'type2': 'poison',
#    'weight_kg': 13.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 405,
#    'capture_rate': '45'},
#   'meta_data': 2},
#  {'abilities': "['Overgrow', 'Chlorophyll']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 100,
#    'defense': 123,
#    'experience_growth': 1059860,
#    'height_m': 2.0,
#    'hp': 80,
#    'sp_attack': 122,
#    'sp_defense': 120,
#    'speed': 80,
#    'type1': 'grass',
#    'type2': 'poison',
#    'weight_kg': 100.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 625,
#    'capture_rate': '45'},
#   'meta_data': 3},
#  {'abilities': "['Blaze', 'Solar Power']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 0.5,
#    'water': 2.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 52,
#    'defense': 43,
#    'experience_growth': 1059860,
#    'height_m': 0.6,
#    'hp': 39,
#    'sp_attack': 60,
#    'sp_defense': 50,
#    'speed': 65,
#    'type1': 'fire',
#    'type2': nan,
#    'weight_kg': 8.5},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 309,
#    'capture_rate': '45'},
#   'meta_data': 4},
#  {'abilities': "['Blaze', 'Solar Power']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 0.5,
#    'water': 2.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 64,
#    'defense': 58,
#    'experience_growth': 1059860,
#    'height_m': 1.1,
#    'hp': 58,
#    'sp_attack': 80,
#    'sp_defense': 65,
#    'speed': 80,
#    'type1': 'fire',
#    'type2': nan,
#    'weight_kg': 19.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 405,
#    'capture_rate': '45'},
#   'meta_data': 5},
#  {'abilities': "['Blaze', 'Solar Power']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 0.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 4.0,
#    'steel': 0.5,
#    'water': 2.0,
#    'bug': 0.25,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 104,
#    'defense': 78,
#    'experience_growth': 1059860,
#    'height_m': 1.7,
#    'hp': 78,
#    'sp_attack': 159,
#    'sp_defense': 115,
#    'speed': 100,
#    'type1': 'fire',
#    'type2': 'flying',
#    'weight_kg': 90.5},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 634,
#    'capture_rate': '45'},
#   'meta_data': 6},
#  {'abilities': "['Torrent', 'Rain Dish']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 0.5,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 48,
#    'defense': 65,
#    'experience_growth': 1059860,
#    'height_m': 0.5,
#    'hp': 44,
#    'sp_attack': 50,
#    'sp_defense': 64,
#    'speed': 43,
#    'type1': 'water',
#    'type2': nan,
#    'weight_kg': 9.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 314,
#    'capture_rate': '45'},
#   'meta_data': 7},
#  {'abilities': "['Torrent', 'Rain Dish']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 0.5,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 63,
#    'defense': 80,
#    'experience_growth': 1059860,
#    'height_m': 1.0,
#    'hp': 59,
#    'sp_attack': 65,
#    'sp_defense': 80,
#    'speed': 58,
#    'type1': 'water',
#    'type2': nan,
#    'weight_kg': 22.5},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 405,
#    'capture_rate': '45'},
#   'meta_data': 8},
#  {'abilities': "['Torrent', 'Rain Dish']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 0.5,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 103,
#    'defense': 120,
#    'experience_growth': 1059860,
#    'height_m': 1.6,
#    'hp': 79,
#    'sp_attack': 135,
#    'sp_defense': 115,
#    'speed': 78,
#    'type1': 'water',
#    'type2': nan,
#    'weight_kg': 85.5},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 630,
#    'capture_rate': '45'},
#   'meta_data': 9},
#  {'abilities': "['Shield Dust', 'Run Away']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 0.5,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 30,
#    'defense': 35,
#    'experience_growth': 1000000,
#    'height_m': 0.3,
#    'hp': 45,
#    'sp_attack': 20,
#    'sp_defense': 20,
#    'speed': 45,
#    'type1': 'bug',
#    'type2': nan,
#    'weight_kg': 2.9},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 195,
#    'capture_rate': '255'},
#   'meta_data': 10},
#  {'abilities': "['Shed Skin']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 0.5,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 20,
#    'defense': 55,
#    'experience_growth': 1000000,
#    'height_m': 0.7,
#    'hp': 50,
#    'sp_attack': 25,
#    'sp_defense': 25,
#    'speed': 30,
#    'type1': 'bug',
#    'type2': nan,
#    'weight_kg': 9.9},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 205,
#    'capture_rate': '120'},
#   'meta_data': 11},
#  {'abilities': "['Compoundeyes', 'Tinted Lens']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 0.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 4.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 0.25,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 45,
#    'defense': 50,
#    'experience_growth': 1000000,
#    'height_m': 1.1,
#    'hp': 60,
#    'sp_attack': 90,
#    'sp_defense': 80,
#    'speed': 70,
#    'type1': 'bug',
#    'type2': 'flying',
#    'weight_kg': 32.0},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 395,
#    'capture_rate': '45'},
#   'meta_data': 12},
#  {'abilities': "['Shield Dust', 'Run Away']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.25,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 35,
#    'defense': 30,
#    'experience_growth': 1000000,
#    'height_m': 0.3,
#    'hp': 40,
#    'sp_attack': 20,
#    'sp_defense': 20,
#    'speed': 50,
#    'type1': 'bug',
#    'type2': 'poison',
#    'weight_kg': 3.2},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 195,
#    'capture_rate': '255'},
#   'meta_data': 13},
#  {'abilities': "['Shed Skin']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.25,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 25,
#    'defense': 50,
#    'experience_growth': 1000000,
#    'height_m': 0.6,
#    'hp': 45,
#    'sp_attack': 25,
#    'sp_defense': 25,
#    'speed': 35,
#    'type1': 'bug',
#    'type2': 'poison',
#    'weight_kg': 10.0},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 205,
#    'capture_rate': '120'},
#   'meta_data': 14},
#  {'abilities': "['Swarm', 'Sniper']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.25,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 150,
#    'defense': 40,
#    'experience_growth': 1000000,
#    'height_m': 1.0,
#    'hp': 65,
#    'sp_attack': 15,
#    'sp_defense': 80,
#    'speed': 145,
#    'type1': 'bug',
#    'type2': 'poison',
#    'weight_kg': 29.5},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 495,
#    'capture_rate': '45'},
#   'meta_data': 15},
#  {'abilities': "['Keen Eye', 'Tangled Feet', 'Big Pecks']",
#   'weakness': {'ghost': 0.0,
#    'grass': 0.5,
#    'ground': 0.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 45,
#    'defense': 40,
#    'experience_growth': 1059860,
#    'height_m': 0.3,
#    'hp': 40,
#    'sp_attack': 35,
#    'sp_defense': 35,
#    'speed': 56,
#    'type1': 'normal',
#    'type2': 'flying',
#    'weight_kg': 1.8},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 251,
#    'capture_rate': '255'},
#   'meta_data': 16},
#  {'abilities': "['Keen Eye', 'Tangled Feet', 'Big Pecks']",
#   'weakness': {'ghost': 0.0,
#    'grass': 0.5,
#    'ground': 0.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 60,
#    'defense': 55,
#    'experience_growth': 1059860,
#    'height_m': 1.1,
#    'hp': 63,
#    'sp_attack': 50,
#    'sp_defense': 50,
#    'speed': 71,
#    'type1': 'normal',
#    'type2': 'flying',
#    'weight_kg': 30.0},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 349,
#    'capture_rate': '120'},
#   'meta_data': 17},
#  {'abilities': "['Keen Eye', 'Tangled Feet', 'Big Pecks']",
#   'weakness': {'ghost': 0.0,
#    'grass': 0.5,
#    'ground': 0.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 80,
#    'defense': 80,
#    'experience_growth': 1059860,
#    'height_m': 1.5,
#    'hp': 83,
#    'sp_attack': 135,
#    'sp_defense': 80,
#    'speed': 121,
#    'type1': 'normal',
#    'type2': 'flying',
#    'weight_kg': 39.5},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 579,
#    'capture_rate': '45'},
#   'meta_data': 18},
#  {'abilities': "['Run Away', 'Guts', 'Hustle', 'Gluttony', 'Hustle', 'Thick Fat']",
#   'weakness': {'ghost': 0.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 2.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 56,
#    'defense': 35,
#    'experience_growth': 1000000,
#    'height_m': nan,
#    'hp': 30,
#    'sp_attack': 25,
#    'sp_defense': 35,
#    'speed': 72,
#    'type1': 'normal',
#    'type2': 'dark',
#    'weight_kg': nan},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 253,
#    'capture_rate': '255'},
#   'meta_data': 19},
#  {'abilities': "['Run Away', 'Guts', 'Hustle', 'Gluttony', 'Hustle', 'Thick Fat']",
#   'weakness': {'ghost': 0.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 2.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 71,
#    'defense': 70,
#    'experience_growth': 1000000,
#    'height_m': nan,
#    'hp': 75,
#    'sp_attack': 40,
#    'sp_defense': 80,
#    'speed': 77,
#    'type1': 'normal',
#    'type2': 'dark',
#    'weight_kg': nan},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 413,
#    'capture_rate': '127'},
#   'meta_data': 20},
#  {'abilities': "['Keen Eye', 'Sniper']",
#   'weakness': {'ghost': 0.0,
#    'grass': 0.5,
#    'ground': 0.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 60,
#    'defense': 30,
#    'experience_growth': 1000000,
#    'height_m': 0.3,
#    'hp': 40,
#    'sp_attack': 31,
#    'sp_defense': 31,
#    'speed': 70,
#    'type1': 'normal',
#    'type2': 'flying',
#    'weight_kg': 2.0},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 262,
#    'capture_rate': '255'},
#   'meta_data': 21},
#  {'abilities': "['Keen Eye', 'Sniper']",
#   'weakness': {'ghost': 0.0,
#    'grass': 0.5,
#    'ground': 0.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 90,
#    'defense': 65,
#    'experience_growth': 1000000,
#    'height_m': 1.2,
#    'hp': 65,
#    'sp_attack': 61,
#    'sp_defense': 61,
#    'speed': 100,
#    'type1': 'normal',
#    'type2': 'flying',
#    'weight_kg': 38.0},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 442,
#    'capture_rate': '90'},
#   'meta_data': 22},
#  {'abilities': "['Intimidate', 'Shed Skin', 'Unnerve']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 60,
#    'defense': 44,
#    'experience_growth': 1000000,
#    'height_m': 2.0,
#    'hp': 35,
#    'sp_attack': 40,
#    'sp_defense': 54,
#    'speed': 55,
#    'type1': 'poison',
#    'type2': nan,
#    'weight_kg': 6.9},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 288,
#    'capture_rate': '255'},
#   'meta_data': 23},
#  {'abilities': "['Intimidate', 'Shed Skin', 'Unnerve']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 95,
#    'defense': 69,
#    'experience_growth': 1000000,
#    'height_m': 3.5,
#    'hp': 60,
#    'sp_attack': 65,
#    'sp_defense': 79,
#    'speed': 80,
#    'type1': 'poison',
#    'type2': nan,
#    'weight_kg': 65.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 448,
#    'capture_rate': '90'},
#   'meta_data': 24},
#  {'abilities': "['Static', 'Lightningrod']",
#   'weakness': {'ghost': 1.0,
#    'grass': 1.0,
#    'ground': 2.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 0.5,
#    'water': 1.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 0.5,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 55,
#    'defense': 40,
#    'experience_growth': 1000000,
#    'height_m': 0.4,
#    'hp': 35,
#    'sp_attack': 50,
#    'sp_defense': 50,
#    'speed': 90,
#    'type1': 'electric',
#    'type2': nan,
#    'weight_kg': 6.0},
#   'base': {'base_egg_steps': 2560,
#    'base_happiness': 70,
#    'base_total': 320,
#    'capture_rate': '190'},
#   'meta_data': 25},
#  {'abilities': "['Static', 'Lightningrod', 'Surge Surfer']",
#   'weakness': {'ghost': 1.0,
#    'grass': 1.0,
#    'ground': 2.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 0.5,
#    'water': 1.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 0.5,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 85,
#    'defense': 50,
#    'experience_growth': 1000000,
#    'height_m': nan,
#    'hp': 60,
#    'sp_attack': 95,
#    'sp_defense': 85,
#    'speed': 110,
#    'type1': 'electric',
#    'type2': 'electric',
#    'weight_kg': nan},
#   'base': {'base_egg_steps': 2560,
#    'base_happiness': 70,
#    'base_total': 485,
#    'capture_rate': '75'},
#   'meta_data': 26},
#  {'abilities': "['Sand Veil', 'Sand Rush', 'Snow Cloak', 'Slush Rush']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 1.0,
#    'rock': 0.5,
#    'steel': 1.0,
#    'water': 2.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.0},
#   'stats': {'attack': 75,
#    'defense': 90,
#    'experience_growth': 1000000,
#    'height_m': nan,
#    'hp': 50,
#    'sp_attack': 10,
#    'sp_defense': 35,
#    'speed': 40,
#    'type1': 'ground',
#    'type2': 'ice',
#    'weight_kg': nan},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 300,
#    'capture_rate': '255'},
#   'meta_data': 27},
#  {'abilities': "['Sand Veil', 'Sand Rush', 'Snow Cloak', 'Slush Rush']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 1.0,
#    'rock': 0.5,
#    'steel': 1.0,
#    'water': 2.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.0},
#   'stats': {'attack': 100,
#    'defense': 120,
#    'experience_growth': 1000000,
#    'height_m': nan,
#    'hp': 75,
#    'sp_attack': 25,
#    'sp_defense': 65,
#    'speed': 65,
#    'type1': 'ground',
#    'type2': 'ice',
#    'weight_kg': nan},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 450,
#    'capture_rate': '90'},
#   'meta_data': 28},
#  {'abilities': "['Poison Point', 'Rivalry', 'Hustle']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 47,
#    'defense': 52,
#    'experience_growth': 1059860,
#    'height_m': 0.4,
#    'hp': 55,
#    'sp_attack': 40,
#    'sp_defense': 40,
#    'speed': 41,
#    'type1': 'poison',
#    'type2': nan,
#    'weight_kg': 7.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 275,
#    'capture_rate': '235'},
#   'meta_data': 29},
#  {'abilities': "['Poison Point', 'Rivalry', 'Hustle']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 62,
#    'defense': 67,
#    'experience_growth': 1059860,
#    'height_m': 0.8,
#    'hp': 70,
#    'sp_attack': 55,
#    'sp_defense': 55,
#    'speed': 56,
#    'type1': 'poison',
#    'type2': nan,
#    'weight_kg': 20.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 365,
#    'capture_rate': '120'},
#   'meta_data': 30},
#  {'abilities': "['Poison Point', 'Rivalry', 'Sheer Force']",
#   'weakness': {'ghost': 1.0,
#    'grass': 1.0,
#    'ground': 2.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 0.25,
#    'psychic': 2.0,
#    'rock': 0.5,
#    'steel': 1.0,
#    'water': 2.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.0},
#   'stats': {'attack': 92,
#    'defense': 87,
#    'experience_growth': 1059860,
#    'height_m': 1.3,
#    'hp': 90,
#    'sp_attack': 75,
#    'sp_defense': 85,
#    'speed': 76,
#    'type1': 'poison',
#    'type2': 'ground',
#    'weight_kg': 60.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 505,
#    'capture_rate': '45'},
#   'meta_data': 31},
#  {'abilities': "['Poison Point', 'Rivalry', 'Hustle']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 57,
#    'defense': 40,
#    'experience_growth': 1059860,
#    'height_m': 0.5,
#    'hp': 46,
#    'sp_attack': 40,
#    'sp_defense': 40,
#    'speed': 50,
#    'type1': 'poison',
#    'type2': nan,
#    'weight_kg': 9.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 273,
#    'capture_rate': '235'},
#   'meta_data': 32},
#  {'abilities': "['Poison Point', 'Rivalry', 'Hustle']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 72,
#    'defense': 57,
#    'experience_growth': 1059860,
#    'height_m': 0.9,
#    'hp': 61,
#    'sp_attack': 55,
#    'sp_defense': 55,
#    'speed': 65,
#    'type1': 'poison',
#    'type2': nan,
#    'weight_kg': 19.5},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 365,
#    'capture_rate': '120'},
#   'meta_data': 33},
#  {'abilities': "['Poison Point', 'Rivalry', 'Sheer Force']",
#   'weakness': {'ghost': 1.0,
#    'grass': 1.0,
#    'ground': 2.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 0.25,
#    'psychic': 2.0,
#    'rock': 0.5,
#    'steel': 1.0,
#    'water': 2.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.0},
#   'stats': {'attack': 102,
#    'defense': 77,
#    'experience_growth': 1059860,
#    'height_m': 1.4,
#    'hp': 81,
#    'sp_attack': 85,
#    'sp_defense': 75,
#    'speed': 85,
#    'type1': 'poison',
#    'type2': 'ground',
#    'weight_kg': 62.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 505,
#    'capture_rate': '45'},
#   'meta_data': 34},
#  {'abilities': "['Cute Charm', 'Magic Guard', 'Friend Guard']",
#   'weakness': {'ghost': 1.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 2.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 2.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 0.5,
#    'dragon': 0.0,
#    'electric': 1.0},
#   'stats': {'attack': 45,
#    'defense': 48,
#    'experience_growth': 800000,
#    'height_m': 0.6,
#    'hp': 70,
#    'sp_attack': 60,
#    'sp_defense': 65,
#    'speed': 35,
#    'type1': 'fairy',
#    'type2': nan,
#    'weight_kg': 7.5},
#   'base': {'base_egg_steps': 2560,
#    'base_happiness': 140,
#    'base_total': 323,
#    'capture_rate': '150'},
#   'meta_data': 35},
#  {'abilities': "['Cute Charm', 'Magic Guard', 'Unaware']",
#   'weakness': {'ghost': 1.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 2.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 2.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 0.5,
#    'dragon': 0.0,
#    'electric': 1.0},
#   'stats': {'attack': 70,
#    'defense': 73,
#    'experience_growth': 800000,
#    'height_m': 1.3,
#    'hp': 95,
#    'sp_attack': 95,
#    'sp_defense': 90,
#    'speed': 60,
#    'type1': 'fairy',
#    'type2': nan,
#    'weight_kg': 40.0},
#   'base': {'base_egg_steps': 2560,
#    'base_happiness': 140,
#    'base_total': 483,
#    'capture_rate': '25'},
#   'meta_data': 36},
#  {'abilities': "['Flash Fire', 'Drought', 'Snow Cloak', 'Snow Warning']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 0.5,
#    'water': 2.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 41,
#    'defense': 40,
#    'experience_growth': 1000000,
#    'height_m': nan,
#    'hp': 38,
#    'sp_attack': 50,
#    'sp_defense': 65,
#    'speed': 65,
#    'type1': 'fire',
#    'type2': 'ice',
#    'weight_kg': nan},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 299,
#    'capture_rate': '190'},
#   'meta_data': 37},
#  {'abilities': "['Flash Fire', 'Drought', 'Snow Cloak', 'Snow Warning']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 0.5,
#    'water': 2.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 67,
#    'defense': 75,
#    'experience_growth': 1000000,
#    'height_m': nan,
#    'hp': 73,
#    'sp_attack': 81,
#    'sp_defense': 100,
#    'speed': 109,
#    'type1': 'fire',
#    'type2': 'ice',
#    'weight_kg': nan},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 505,
#    'capture_rate': '75'},
#   'meta_data': 38},
#  {'abilities': "['Cute Charm', 'Competitive', 'Friend Guard']",
#   'weakness': {'ghost': 0.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 2.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 2.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 0.5,
#    'dragon': 0.0,
#    'electric': 1.0},
#   'stats': {'attack': 45,
#    'defense': 20,
#    'experience_growth': 800000,
#    'height_m': 0.5,
#    'hp': 115,
#    'sp_attack': 45,
#    'sp_defense': 25,
#    'speed': 20,
#    'type1': 'normal',
#    'type2': 'fairy',
#    'weight_kg': 5.5},
#   'base': {'base_egg_steps': 2560,
#    'base_happiness': 70,
#    'base_total': 270,
#    'capture_rate': '170'},
#   'meta_data': 39},
#  {'abilities': "['Cute Charm', 'Competitive', 'Frisk']",
#   'weakness': {'ghost': 0.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 2.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 2.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 0.5,
#    'dragon': 0.0,
#    'electric': 1.0},
#   'stats': {'attack': 70,
#    'defense': 45,
#    'experience_growth': 800000,
#    'height_m': 1.0,
#    'hp': 140,
#    'sp_attack': 85,
#    'sp_defense': 50,
#    'speed': 45,
#    'type1': 'normal',
#    'type2': 'fairy',
#    'weight_kg': 12.0},
#   'base': {'base_egg_steps': 2560,
#    'base_happiness': 70,
#    'base_total': 435,
#    'capture_rate': '50'},
#   'meta_data': 40},
#  {'abilities': "['Inner Focus', 'Infiltrator']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 0.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.25,
#    'fairy': 0.5,
#    'fight': 0.25,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 45,
#    'defense': 35,
#    'experience_growth': 1000000,
#    'height_m': 0.8,
#    'hp': 40,
#    'sp_attack': 30,
#    'sp_defense': 40,
#    'speed': 55,
#    'type1': 'poison',
#    'type2': 'flying',
#    'weight_kg': 7.5},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 245,
#    'capture_rate': '255'},
#   'meta_data': 41},
#  {'abilities': "['Inner Focus', 'Infiltrator']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 0.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.25,
#    'fairy': 0.5,
#    'fight': 0.25,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 80,
#    'defense': 70,
#    'experience_growth': 1000000,
#    'height_m': 1.6,
#    'hp': 75,
#    'sp_attack': 65,
#    'sp_defense': 75,
#    'speed': 90,
#    'type1': 'poison',
#    'type2': 'flying',
#    'weight_kg': 55.0},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 455,
#    'capture_rate': '90'},
#   'meta_data': 42},
#  {'abilities': "['Chlorophyll', 'Run Away']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 50,
#    'defense': 55,
#    'experience_growth': 1059860,
#    'height_m': 0.5,
#    'hp': 45,
#    'sp_attack': 75,
#    'sp_defense': 65,
#    'speed': 30,
#    'type1': 'grass',
#    'type2': 'poison',
#    'weight_kg': 5.4},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 320,
#    'capture_rate': '255'},
#   'meta_data': 43},
#  {'abilities': "['Chlorophyll', 'Stench']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 65,
#    'defense': 70,
#    'experience_growth': 1059860,
#    'height_m': 0.8,
#    'hp': 60,
#    'sp_attack': 85,
#    'sp_defense': 75,
#    'speed': 40,
#    'type1': 'grass',
#    'type2': 'poison',
#    'weight_kg': 8.6},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 395,
#    'capture_rate': '120'},
#   'meta_data': 44},
#  {'abilities': "['Chlorophyll', 'Effect Spore']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 80,
#    'defense': 85,
#    'experience_growth': 1059860,
#    'height_m': 1.2,
#    'hp': 75,
#    'sp_attack': 110,
#    'sp_defense': 90,
#    'speed': 50,
#    'type1': 'grass',
#    'type2': 'poison',
#    'weight_kg': 18.6},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 490,
#    'capture_rate': '45'},
#   'meta_data': 45},
#  {'abilities': "['Effect Spore', 'Dry Skin', 'Damp']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 0.25,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 2.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 2.0,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 4.0,
#    'flying': 4.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 70,
#    'defense': 55,
#    'experience_growth': 1000000,
#    'height_m': 0.3,
#    'hp': 35,
#    'sp_attack': 45,
#    'sp_defense': 55,
#    'speed': 25,
#    'type1': 'bug',
#    'type2': 'grass',
#    'weight_kg': 5.4},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 285,
#    'capture_rate': '190'},
#   'meta_data': 46},
#  {'abilities': "['Effect Spore', 'Dry Skin', 'Damp']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 0.25,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 2.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 2.0,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 4.0,
#    'flying': 4.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 95,
#    'defense': 80,
#    'experience_growth': 1000000,
#    'height_m': 1.0,
#    'hp': 60,
#    'sp_attack': 60,
#    'sp_defense': 80,
#    'speed': 30,
#    'type1': 'bug',
#    'type2': 'grass',
#    'weight_kg': 29.5},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 405,
#    'capture_rate': '75'},
#   'meta_data': 47},
#  {'abilities': "['Compoundeyes', 'Tinted Lens', 'Run Away']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.25,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 55,
#    'defense': 50,
#    'experience_growth': 1000000,
#    'height_m': 1.0,
#    'hp': 60,
#    'sp_attack': 40,
#    'sp_defense': 55,
#    'speed': 45,
#    'type1': 'bug',
#    'type2': 'poison',
#    'weight_kg': 30.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 305,
#    'capture_rate': '190'},
#   'meta_data': 48},
#  {'abilities': "['Shield Dust', 'Tinted Lens', 'Wonder Skin ']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.25,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 65,
#    'defense': 60,
#    'experience_growth': 1000000,
#    'height_m': 1.5,
#    'hp': 70,
#    'sp_attack': 90,
#    'sp_defense': 75,
#    'speed': 90,
#    'type1': 'bug',
#    'type2': 'poison',
#    'weight_kg': 12.5},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 450,
#    'capture_rate': '75'},
#   'meta_data': 49},
#  {'abilities': "['Sand Veil', 'Arena Trap', 'Sand Force', 'Sand Veil', 'Tangling Hair', 'Sand Force']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 1.0,
#    'rock': 0.5,
#    'steel': 1.0,
#    'water': 2.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.0},
#   'stats': {'attack': 55,
#    'defense': 30,
#    'experience_growth': 1000000,
#    'height_m': nan,
#    'hp': 10,
#    'sp_attack': 35,
#    'sp_defense': 45,
#    'speed': 90,
#    'type1': 'ground',
#    'type2': 'ground',
#    'weight_kg': nan},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 265,
#    'capture_rate': '255'},
#   'meta_data': 50},
#  {'abilities': "['Sand Veil', 'Arena Trap', 'Sand Force', 'Sand Veil', 'Tangling Hair', 'Sand Force']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 1.0,
#    'rock': 0.5,
#    'steel': 1.0,
#    'water': 2.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.0},
#   'stats': {'attack': 100,
#    'defense': 60,
#    'experience_growth': 1000000,
#    'height_m': nan,
#    'hp': 35,
#    'sp_attack': 50,
#    'sp_defense': 70,
#    'speed': 110,
#    'type1': 'ground',
#    'type2': 'ground',
#    'weight_kg': nan},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 425,
#    'capture_rate': '50'},
#   'meta_data': 51},
#  {'abilities': "['Pickup', 'Technician', 'Unnerve', 'Pickup', 'Technician', 'Rattled']",
#   'weakness': {'ghost': 0.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 2.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 35,
#    'defense': 35,
#    'experience_growth': 1000000,
#    'height_m': nan,
#    'hp': 40,
#    'sp_attack': 50,
#    'sp_defense': 40,
#    'speed': 90,
#    'type1': 'normal',
#    'type2': 'dark',
#    'weight_kg': nan},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 290,
#    'capture_rate': '255'},
#   'meta_data': 52},
#  {'abilities': "['Limber', 'Technician', 'Unnerve', 'Fur Coat', 'Technician', 'Rattled']",
#   'weakness': {'ghost': 0.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 2.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 60,
#    'defense': 60,
#    'experience_growth': 1000000,
#    'height_m': nan,
#    'hp': 65,
#    'sp_attack': 75,
#    'sp_defense': 65,
#    'speed': 115,
#    'type1': 'normal',
#    'type2': 'dark',
#    'weight_kg': nan},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 440,
#    'capture_rate': '90'},
#   'meta_data': 53},
#  {'abilities': "['Damp', 'Cloud Nine', 'Swift Swim']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 0.5,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 52,
#    'defense': 48,
#    'experience_growth': 1000000,
#    'height_m': 0.8,
#    'hp': 50,
#    'sp_attack': 65,
#    'sp_defense': 50,
#    'speed': 55,
#    'type1': 'water',
#    'type2': nan,
#    'weight_kg': 19.6},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 320,
#    'capture_rate': '190'},
#   'meta_data': 54},
#  {'abilities': "['Damp', 'Cloud Nine', 'Swift Swim']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 0.5,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 82,
#    'defense': 78,
#    'experience_growth': 1000000,
#    'height_m': 1.7,
#    'hp': 80,
#    'sp_attack': 95,
#    'sp_defense': 80,
#    'speed': 85,
#    'type1': 'water',
#    'type2': nan,
#    'weight_kg': 76.6},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 500,
#    'capture_rate': '75'},
#   'meta_data': 55},
#  {'abilities': "['Vital Spirit', 'Anger Point', 'Defiant']",
#   'weakness': {'ghost': 1.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 0.5,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 2.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 2.0,
#    'dark': 0.5,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 80,
#    'defense': 35,
#    'experience_growth': 1000000,
#    'height_m': 0.5,
#    'hp': 40,
#    'sp_attack': 35,
#    'sp_defense': 45,
#    'speed': 70,
#    'type1': 'fighting',
#    'type2': nan,
#    'weight_kg': 28.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 305,
#    'capture_rate': '190'},
#   'meta_data': 56},
#  {'abilities': "['Vital Spirit', 'Anger Point', 'Defiant']",
#   'weakness': {'ghost': 1.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 0.5,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 2.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 2.0,
#    'dark': 0.5,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 105,
#    'defense': 60,
#    'experience_growth': 1000000,
#    'height_m': 1.0,
#    'hp': 65,
#    'sp_attack': 60,
#    'sp_defense': 70,
#    'speed': 95,
#    'type1': 'fighting',
#    'type2': nan,
#    'weight_kg': 32.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 455,
#    'capture_rate': '75'},
#   'meta_data': 57},
#  {'abilities': "['Intimidate', 'Flash Fire', 'Justified']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 0.5,
#    'water': 2.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 70,
#    'defense': 45,
#    'experience_growth': 1250000,
#    'height_m': 0.7,
#    'hp': 55,
#    'sp_attack': 70,
#    'sp_defense': 50,
#    'speed': 60,
#    'type1': 'fire',
#    'type2': nan,
#    'weight_kg': 19.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 350,
#    'capture_rate': '190'},
#   'meta_data': 58},
#  {'abilities': "['Intimidate', 'Flash Fire', 'Justified']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 0.5,
#    'water': 2.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 110,
#    'defense': 80,
#    'experience_growth': 1250000,
#    'height_m': 1.9,
#    'hp': 90,
#    'sp_attack': 100,
#    'sp_defense': 80,
#    'speed': 95,
#    'type1': 'fire',
#    'type2': nan,
#    'weight_kg': 155.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 555,
#    'capture_rate': '75'},
#   'meta_data': 59},
#  {'abilities': "['Water Absorb', 'Damp', 'Swift Swim']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 0.5,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 50,
#    'defense': 40,
#    'experience_growth': 1059860,
#    'height_m': 0.6,
#    'hp': 40,
#    'sp_attack': 40,
#    'sp_defense': 40,
#    'speed': 90,
#    'type1': 'water',
#    'type2': 'None',
#    'weight_kg': 12.4},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 300,
#    'capture_rate': '255'},
#   'meta_data': 60},
#  {'abilities': "['Water Absorb', 'Damp', 'Swift Swim']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 0.5,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 65,
#    'defense': 65,
#    'experience_growth': 1059860,
#    'height_m': 1.0,
#    'hp': 65,
#    'sp_attack': 50,
#    'sp_defense': 50,
#    'speed': 90,
#    'type1': 'water',
#    'type2': nan,
#    'weight_kg': 20.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 385,
#    'capture_rate': '120'},
#   'meta_data': 61},
#  {'abilities': "['Water Absorb', 'Damp', 'Swift Swim']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 0.5,
#    'steel': 0.5,
#    'water': 0.5,
#    'bug': 0.5,
#    'fairy': 2.0,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 2.0,
#    'dark': 0.5,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 95,
#    'defense': 95,
#    'experience_growth': 1059860,
#    'height_m': 1.3,
#    'hp': 90,
#    'sp_attack': 70,
#    'sp_defense': 90,
#    'speed': 70,
#    'type1': 'water',
#    'type2': 'fighting',
#    'weight_kg': 54.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 510,
#    'capture_rate': '45'},
#   'meta_data': 62},
#  {'abilities': "['Synchronize', 'Inner Focus', 'Magic Guard']",
#   'weakness': {'ghost': 2.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 0.5,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 2.0,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 2.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 20,
#    'defense': 15,
#    'experience_growth': 1059860,
#    'height_m': 0.9,
#    'hp': 25,
#    'sp_attack': 105,
#    'sp_defense': 55,
#    'speed': 90,
#    'type1': 'psychic',
#    'type2': nan,
#    'weight_kg': 19.5},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 310,
#    'capture_rate': '200'},
#   'meta_data': 63},
#  {'abilities': "['Synchronize', 'Inner Focus', 'Magic Guard']",
#   'weakness': {'ghost': 2.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 0.5,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 2.0,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 2.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 35,
#    'defense': 30,
#    'experience_growth': 1059860,
#    'height_m': 1.3,
#    'hp': 40,
#    'sp_attack': 120,
#    'sp_defense': 70,
#    'speed': 105,
#    'type1': 'psychic',
#    'type2': 'None',
#    'weight_kg': 56.5},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 400,
#    'capture_rate': '100'},
#   'meta_data': 64},
#  {'abilities': "['Synchronize', 'Inner Focus', 'Magic Guard']",
#   'weakness': {'ghost': 2.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 0.5,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 2.0,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 2.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 50,
#    'defense': 65,
#    'experience_growth': 1059860,
#    'height_m': 1.5,
#    'hp': 55,
#    'sp_attack': 175,
#    'sp_defense': 105,
#    'speed': 150,
#    'type1': 'psychic',
#    'type2': nan,
#    'weight_kg': 48.0},
#   'base': {'base_egg_steps': 5120,
# ...
#   'weakness': {'ghost': 0.0,
#    'grass': 0.5,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 2.0,
#    'fight': 2.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 2.0,
#    'electric': 0.5},
#   'stats': {'attack': 60,
#    'defense': 85,
#    'experience_growth': 1000000,
#    'height_m': 3.0,
#    'hp': 78,
#    'sp_attack': 135,
#    'sp_defense': 91,
#    'speed': 36,
#    'type1': 'normal',
#    'type2': 'dragon',
#    'weight_kg': 185.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 485,
#    'capture_rate': '70'},
#   'meta_data': 780},
#  {'abilities': "['Steelworker']",
#   'weakness': {'ghost': 2.0,
#    'grass': 0.5,
#    'ground': 0.5,
#    'ice': 2.0,
#    'normal': 0.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 0.0,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 2.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 131,
#    'defense': 100,
#    'experience_growth': 1000000,
#    'height_m': 3.9,
#    'hp': 70,
#    'sp_attack': 86,
#    'sp_defense': 90,
#    'speed': 40,
#    'type1': 'ghost',
#    'type2': 'grass',
#    'weight_kg': 210.0},
#   'base': {'base_egg_steps': 6400,
#    'base_happiness': 70,
#    'base_total': 517,
#    'capture_rate': '25'},
#   'meta_data': 781},
#  {'abilities': "['Bulletproof', 'Soundproof', 'Overcoat']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 2.0,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 2.0,
#    'electric': 0.5},
#   'stats': {'attack': 55,
#    'defense': 65,
#    'experience_growth': 1250000,
#    'height_m': 0.6,
#    'hp': 45,
#    'sp_attack': 45,
#    'sp_defense': 45,
#    'speed': 45,
#    'type1': 'dragon',
#    'type2': nan,
#    'weight_kg': 29.7},
#   'base': {'base_egg_steps': 10240,
#    'base_happiness': 70,
#    'base_total': 300,
#    'capture_rate': '45'},
#   'meta_data': 782},
#  {'abilities': "['Bulletproof', 'Soundproof', 'Overcoat']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 0.5,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 0.5,
#    'fairy': 4.0,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 2.0,
#    'dark': 0.5,
#    'dragon': 2.0,
#    'electric': 0.5},
#   'stats': {'attack': 75,
#    'defense': 90,
#    'experience_growth': 1250000,
#    'height_m': 1.2,
#    'hp': 55,
#    'sp_attack': 65,
#    'sp_defense': 70,
#    'speed': 65,
#    'type1': 'dragon',
#    'type2': 'fighting',
#    'weight_kg': 47.0},
#   'base': {'base_egg_steps': 10240,
#    'base_happiness': 70,
#    'base_total': 420,
#    'capture_rate': '45'},
#   'meta_data': 783},
#  {'abilities': "['Bulletproof', 'Soundproof', 'Overcoat']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 0.5,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 0.5,
#    'fairy': 4.0,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 2.0,
#    'dark': 0.5,
#    'dragon': 2.0,
#    'electric': 0.5},
#   'stats': {'attack': 110,
#    'defense': 125,
#    'experience_growth': 1250000,
#    'height_m': 1.6,
#    'hp': 75,
#    'sp_attack': 100,
#    'sp_defense': 105,
#    'speed': 85,
#    'type1': 'dragon',
#    'type2': 'fighting',
#    'weight_kg': 78.2},
#   'base': {'base_egg_steps': 10240,
#    'base_happiness': 70,
#    'base_total': 600,
#    'capture_rate': '45'},
#   'meta_data': 784},
#  {'abilities': "['Electric Surge', 'Telepathy']",
#   'weakness': {'ghost': 1.0,
#    'grass': 1.0,
#    'ground': 2.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 2.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 0.5,
#    'dark': 0.5,
#    'dragon': 0.0,
#    'electric': 0.5},
#   'stats': {'attack': 115,
#    'defense': 85,
#    'experience_growth': 1250000,
#    'height_m': 1.8,
#    'hp': 70,
#    'sp_attack': 95,
#    'sp_defense': 75,
#    'speed': 130,
#    'type1': 'electric',
#    'type2': 'fairy',
#    'weight_kg': 20.5},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 570,
#    'capture_rate': '3'},
#   'meta_data': 785},
#  {'abilities': "['Psychic Surge', 'Telepathy']",
#   'weakness': {'ghost': 2.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 2.0,
#    'psychic': 0.5,
#    'rock': 1.0,
#    'steel': 2.0,
#    'water': 1.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 0.25,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 0.0,
#    'electric': 1.0},
#   'stats': {'attack': 85,
#    'defense': 75,
#    'experience_growth': 1250000,
#    'height_m': 1.2,
#    'hp': 70,
#    'sp_attack': 130,
#    'sp_defense': 115,
#    'speed': 95,
#    'type1': 'psychic',
#    'type2': 'fairy',
#    'weight_kg': 18.6},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 570,
#    'capture_rate': '3'},
#   'meta_data': 786},
#  {'abilities': "['Grassy Surge', 'Telepathy']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 0.5,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 4.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 2.0,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 0.5,
#    'dragon': 0.0,
#    'electric': 0.5},
#   'stats': {'attack': 130,
#    'defense': 115,
#    'experience_growth': 1250000,
#    'height_m': 1.9,
#    'hp': 70,
#    'sp_attack': 85,
#    'sp_defense': 95,
#    'speed': 75,
#    'type1': 'grass',
#    'type2': 'fairy',
#    'weight_kg': 45.5},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 570,
#    'capture_rate': '3'},
#   'meta_data': 787},
#  {'abilities': "['Misty Surge', 'Telepathy']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 2.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 0.5,
#    'dragon': 0.0,
#    'electric': 2.0},
#   'stats': {'attack': 75,
#    'defense': 115,
#    'experience_growth': 1250000,
#    'height_m': 1.3,
#    'hp': 70,
#    'sp_attack': 95,
#    'sp_defense': 130,
#    'speed': 85,
#    'type1': 'water',
#    'type2': 'fairy',
#    'weight_kg': 21.2},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 570,
#    'capture_rate': '3'},
#   'meta_data': 788},
#  {'abilities': "['Unaware']",
#   'weakness': {'ghost': 2.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 0.5,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 2.0,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 2.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 29,
#    'defense': 31,
#    'experience_growth': 1250000,
#    'height_m': 0.2,
#    'hp': 43,
#    'sp_attack': 29,
#    'sp_defense': 31,
#    'speed': 37,
#    'type1': 'psychic',
#    'type2': nan,
#    'weight_kg': 0.1},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 200,
#    'capture_rate': '45'},
#   'meta_data': 789},
#  {'abilities': "['Sturdy']",
#   'weakness': {'ghost': 2.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 0.5,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 2.0,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 2.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 29,
#    'defense': 131,
#    'experience_growth': 1250000,
#    'height_m': 0.1,
#    'hp': 43,
#    'sp_attack': 29,
#    'sp_defense': 131,
#    'speed': 37,
#    'type1': 'psychic',
#    'type2': nan,
#    'weight_kg': 999.9},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 400,
#    'capture_rate': '45'},
#   'meta_data': 790},
#  {'abilities': "['Full Metal Body']",
#   'weakness': {'ghost': 2.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 0.5,
#    'normal': 0.5,
#    'poison': 0.0,
#    'psychic': 0.25,
#    'rock': 0.5,
#    'steel': 0.5,
#    'water': 1.0,
#    'bug': 1.0,
#    'fairy': 0.5,
#    'fight': 1.0,
#    'fire': 2.0,
#    'flying': 0.5,
#    'dark': 2.0,
#    'dragon': 0.5,
#    'electric': 1.0},
#   'stats': {'attack': 137,
#    'defense': 107,
#    'experience_growth': 1250000,
#    'height_m': 3.4,
#    'hp': 137,
#    'sp_attack': 113,
#    'sp_defense': 89,
#    'speed': 97,
#    'type1': 'psychic',
#    'type2': 'steel',
#    'weight_kg': 230.0},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 680,
#    'capture_rate': '45'},
#   'meta_data': 791},
#  {'abilities': "['Shadow Shield']",
#   'weakness': {'ghost': 4.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 0.0,
#    'poison': 0.5,
#    'psychic': 0.5,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 0.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 4.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 113,
#    'defense': 89,
#    'experience_growth': 1250000,
#    'height_m': 4.0,
#    'hp': 137,
#    'sp_attack': 137,
#    'sp_defense': 107,
#    'speed': 97,
#    'type1': 'psychic',
#    'type2': 'ghost',
#    'weight_kg': 120.0},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 680,
#    'capture_rate': '45'},
#   'meta_data': 792},
#  {'abilities': "['Beast Boost']",
#   'weakness': {'ghost': 1.0,
#    'grass': 1.0,
#    'ground': 4.0,
#    'ice': 1.0,
#    'normal': 0.5,
#    'poison': 0.25,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 2.0,
#    'water': 2.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 0.5,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 53,
#    'defense': 47,
#    'experience_growth': 1250000,
#    'height_m': 1.2,
#    'hp': 109,
#    'sp_attack': 127,
#    'sp_defense': 131,
#    'speed': 103,
#    'type1': 'rock',
#    'type2': 'poison',
#    'weight_kg': 55.5},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 570,
#    'capture_rate': '45'},
#   'meta_data': 793},
#  {'abilities': "['Beast Boost']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 0.5,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 2.0,
#    'fight': 0.5,
#    'fire': 2.0,
#    'flying': 4.0,
#    'dark': 0.5,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 139,
#    'defense': 139,
#    'experience_growth': 1250000,
#    'height_m': 2.4,
#    'hp': 107,
#    'sp_attack': 53,
#    'sp_defense': 53,
#    'speed': 79,
#    'type1': 'bug',
#    'type2': 'fighting',
#    'weight_kg': 333.6},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 570,
#    'capture_rate': '25'},
#   'meta_data': 794},
#  {'abilities': "['Beast Boost']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 0.5,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 2.0,
#    'fight': 0.5,
#    'fire': 2.0,
#    'flying': 4.0,
#    'dark': 0.5,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 137,
#    'defense': 37,
#    'experience_growth': 1250000,
#    'height_m': 1.8,
#    'hp': 71,
#    'sp_attack': 137,
#    'sp_defense': 37,
#    'speed': 151,
#    'type1': 'bug',
#    'type2': 'fighting',
#    'weight_kg': 25.0},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 570,
#    'capture_rate': '255'},
#   'meta_data': 795},
#  {'abilities': "['Beast Boost']",
#   'weakness': {'ghost': 1.0,
#    'grass': 1.0,
#    'ground': 2.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 0.5,
#    'water': 1.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 0.5,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 89,
#    'defense': 71,
#    'experience_growth': 1250000,
#    'height_m': 3.8,
#    'hp': 83,
#    'sp_attack': 173,
#    'sp_defense': 71,
#    'speed': 83,
#    'type1': 'electric',
#    'type2': nan,
#    'weight_kg': 100.0},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 570,
#    'capture_rate': '30'},
#   'meta_data': 796},
#  {'abilities': "['Beast Boost']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 0.0,
#    'ice': 1.0,
#    'normal': 0.5,
#    'poison': 0.0,
#    'psychic': 0.5,
#    'rock': 1.0,
#    'steel': 0.5,
#    'water': 1.0,
#    'bug': 0.25,
#    'fairy': 0.5,
#    'fight': 1.0,
#    'fire': 2.0,
#    'flying': 0.5,
#    'dark': 1.0,
#    'dragon': 0.5,
#    'electric': 2.0},
#   'stats': {'attack': 101,
#    'defense': 103,
#    'experience_growth': 1250000,
#    'height_m': 9.2,
#    'hp': 97,
#    'sp_attack': 107,
#    'sp_defense': 101,
#    'speed': 61,
#    'type1': 'steel',
#    'type2': 'flying',
#    'weight_kg': 999.9},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 570,
#    'capture_rate': '25'},
#   'meta_data': 797},
#  {'abilities': "['Beast Boost']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 0.5,
#    'poison': 0.0,
#    'psychic': 0.5,
#    'rock': 0.5,
#    'steel': 0.5,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 0.5,
#    'fight': 2.0,
#    'fire': 4.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 0.5,
#    'electric': 0.5},
#   'stats': {'attack': 181,
#    'defense': 131,
#    'experience_growth': 1250000,
#    'height_m': 0.3,
#    'hp': 59,
#    'sp_attack': 59,
#    'sp_defense': 31,
#    'speed': 109,
#    'type1': 'grass',
#    'type2': 'steel',
#    'weight_kg': 0.1},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 570,
#    'capture_rate': '255'},
#   'meta_data': 798},
#  {'abilities': "['Beast Boost']",
#   'weakness': {'ghost': 0.5,
#    'grass': 0.5,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 0.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 2.0,
#    'fairy': 4.0,
#    'fight': 2.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 0.5,
#    'dragon': 2.0,
#    'electric': 0.5},
#   'stats': {'attack': 101,
#    'defense': 53,
#    'experience_growth': 1250000,
#    'height_m': 5.5,
#    'hp': 223,
#    'sp_attack': 97,
#    'sp_defense': 53,
#    'speed': 43,
#    'type1': 'dark',
#    'type2': 'dragon',
#    'weight_kg': 888.0},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 570,
#    'capture_rate': '15'},
#   'meta_data': 799},
#  {'abilities': "['Prism Armor']",
#   'weakness': {'ghost': 2.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 0.5,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 2.0,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 2.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 107,
#    'defense': 101,
#    'experience_growth': 1250000,
#    'height_m': 2.4,
#    'hp': 97,
#    'sp_attack': 127,
#    'sp_defense': 89,
#    'speed': 79,
#    'type1': 'psychic',
#    'type2': nan,
#    'weight_kg': 230.0},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 600,
#    'capture_rate': '3'},
#   'meta_data': 800},
#  {'abilities': "['Soul-Heart']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 0.5,
#    'normal': 0.5,
#    'poison': 0.0,
#    'psychic': 0.5,
#    'rock': 0.5,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.25,
#    'fairy': 0.5,
#    'fight': 1.0,
#    'fire': 2.0,
#    'flying': 0.5,
#    'dark': 0.5,
#    'dragon': 0.0,
#    'electric': 1.0},
#   'stats': {'attack': 95,
#    'defense': 115,
#    'experience_growth': 1250000,
#    'height_m': 1.0,
#    'hp': 80,
#    'sp_attack': 130,
#    'sp_defense': 115,
#    'speed': 65,
#    'type1': 'steel',
#    'type2': 'fairy',
#    'weight_kg': 80.5},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 600,
#    'capture_rate': '3'},
#   'meta_data': 801}]

# %% [markdown]
# #### Sort of a side question:
#
# > The list we just made is the information for every pokemon in the dataset without the names.
#
# > What is a built in function that allows us to create a list of tuples that "zip" the names and the values together?

# %% [markdown]
# > **Sierra's Addition:** Defining a tuple and how it compares to a list - tuples are immutable (aka you can't modify a tuple object after it was created) and uses parenthesis instead of brackets. Also, zip only works if the length of the two arrays are both the same.

# %%
# Your code here

dict(zip(data_keys, pokedex))
# Out:
# {'Bulbasaur': {'abilities': "['Overgrow', 'Chlorophyll']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 49,
#    'defense': 49,
#    'experience_growth': 1059860,
#    'height_m': 0.7,
#    'hp': 45,
#    'sp_attack': 65,
#    'sp_defense': 65,
#    'speed': 45,
#    'type1': 'grass',
#    'type2': 'poison',
#    'weight_kg': 6.9},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 318,
#    'capture_rate': '45'},
#   'meta_data': 1},
#  'Ivysaur': {'abilities': "['Overgrow', 'Chlorophyll']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 62,
#    'defense': 63,
#    'experience_growth': 1059860,
#    'height_m': 1.0,
#    'hp': 60,
#    'sp_attack': 80,
#    'sp_defense': 80,
#    'speed': 60,
#    'type1': 'grass',
#    'type2': 'poison',
#    'weight_kg': 13.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 405,
#    'capture_rate': '45'},
#   'meta_data': 2},
#  'Venusaur': {'abilities': "['Overgrow', 'Chlorophyll']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 100,
#    'defense': 123,
#    'experience_growth': 1059860,
#    'height_m': 2.0,
#    'hp': 80,
#    'sp_attack': 122,
#    'sp_defense': 120,
#    'speed': 80,
#    'type1': 'grass',
#    'type2': 'poison',
#    'weight_kg': 100.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 625,
#    'capture_rate': '45'},
#   'meta_data': 3},
#  'Charmander': {'abilities': "['Blaze', 'Solar Power']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 0.5,
#    'water': 2.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 52,
#    'defense': 43,
#    'experience_growth': 1059860,
#    'height_m': 0.6,
#    'hp': 39,
#    'sp_attack': 60,
#    'sp_defense': 50,
#    'speed': 65,
#    'type1': 'fire',
#    'type2': nan,
#    'weight_kg': 8.5},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 309,
#    'capture_rate': '45'},
#   'meta_data': 4},
#  'Charmeleon': {'abilities': "['Blaze', 'Solar Power']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 0.5,
#    'water': 2.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 64,
#    'defense': 58,
#    'experience_growth': 1059860,
#    'height_m': 1.1,
#    'hp': 58,
#    'sp_attack': 80,
#    'sp_defense': 65,
#    'speed': 80,
#    'type1': 'fire',
#    'type2': nan,
#    'weight_kg': 19.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 405,
#    'capture_rate': '45'},
#   'meta_data': 5},
#  'Charizard': {'abilities': "['Blaze', 'Solar Power']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 0.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 4.0,
#    'steel': 0.5,
#    'water': 2.0,
#    'bug': 0.25,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 104,
#    'defense': 78,
#    'experience_growth': 1059860,
#    'height_m': 1.7,
#    'hp': 78,
#    'sp_attack': 159,
#    'sp_defense': 115,
#    'speed': 100,
#    'type1': 'fire',
#    'type2': 'flying',
#    'weight_kg': 90.5},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 634,
#    'capture_rate': '45'},
#   'meta_data': 6},
#  'Squirtle': {'abilities': "['Torrent', 'Rain Dish']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 0.5,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 48,
#    'defense': 65,
#    'experience_growth': 1059860,
#    'height_m': 0.5,
#    'hp': 44,
#    'sp_attack': 50,
#    'sp_defense': 64,
#    'speed': 43,
#    'type1': 'water',
#    'type2': nan,
#    'weight_kg': 9.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 314,
#    'capture_rate': '45'},
#   'meta_data': 7},
#  'Wartortle': {'abilities': "['Torrent', 'Rain Dish']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 0.5,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 63,
#    'defense': 80,
#    'experience_growth': 1059860,
#    'height_m': 1.0,
#    'hp': 59,
#    'sp_attack': 65,
#    'sp_defense': 80,
#    'speed': 58,
#    'type1': 'water',
#    'type2': nan,
#    'weight_kg': 22.5},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 405,
#    'capture_rate': '45'},
#   'meta_data': 8},
#  'Blastoise': {'abilities': "['Torrent', 'Rain Dish']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 0.5,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 103,
#    'defense': 120,
#    'experience_growth': 1059860,
#    'height_m': 1.6,
#    'hp': 79,
#    'sp_attack': 135,
#    'sp_defense': 115,
#    'speed': 78,
#    'type1': 'water',
#    'type2': nan,
#    'weight_kg': 85.5},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 630,
#    'capture_rate': '45'},
#   'meta_data': 9},
#  'Caterpie': {'abilities': "['Shield Dust', 'Run Away']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 0.5,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 30,
#    'defense': 35,
#    'experience_growth': 1000000,
#    'height_m': 0.3,
#    'hp': 45,
#    'sp_attack': 20,
#    'sp_defense': 20,
#    'speed': 45,
#    'type1': 'bug',
#    'type2': nan,
#    'weight_kg': 2.9},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 195,
#    'capture_rate': '255'},
#   'meta_data': 10},
#  'Metapod': {'abilities': "['Shed Skin']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 0.5,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 20,
#    'defense': 55,
#    'experience_growth': 1000000,
#    'height_m': 0.7,
#    'hp': 50,
#    'sp_attack': 25,
#    'sp_defense': 25,
#    'speed': 30,
#    'type1': 'bug',
#    'type2': nan,
#    'weight_kg': 9.9},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 205,
#    'capture_rate': '120'},
#   'meta_data': 11},
#  'Butterfree': {'abilities': "['Compoundeyes', 'Tinted Lens']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 0.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 4.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 0.25,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 45,
#    'defense': 50,
#    'experience_growth': 1000000,
#    'height_m': 1.1,
#    'hp': 60,
#    'sp_attack': 90,
#    'sp_defense': 80,
#    'speed': 70,
#    'type1': 'bug',
#    'type2': 'flying',
#    'weight_kg': 32.0},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 395,
#    'capture_rate': '45'},
#   'meta_data': 12},
#  'Weedle': {'abilities': "['Shield Dust', 'Run Away']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.25,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 35,
#    'defense': 30,
#    'experience_growth': 1000000,
#    'height_m': 0.3,
#    'hp': 40,
#    'sp_attack': 20,
#    'sp_defense': 20,
#    'speed': 50,
#    'type1': 'bug',
#    'type2': 'poison',
#    'weight_kg': 3.2},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 195,
#    'capture_rate': '255'},
#   'meta_data': 13},
#  'Kakuna': {'abilities': "['Shed Skin']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.25,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 25,
#    'defense': 50,
#    'experience_growth': 1000000,
#    'height_m': 0.6,
#    'hp': 45,
#    'sp_attack': 25,
#    'sp_defense': 25,
#    'speed': 35,
#    'type1': 'bug',
#    'type2': 'poison',
#    'weight_kg': 10.0},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 205,
#    'capture_rate': '120'},
#   'meta_data': 14},
#  'Beedrill': {'abilities': "['Swarm', 'Sniper']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.25,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 150,
#    'defense': 40,
#    'experience_growth': 1000000,
#    'height_m': 1.0,
#    'hp': 65,
#    'sp_attack': 15,
#    'sp_defense': 80,
#    'speed': 145,
#    'type1': 'bug',
#    'type2': 'poison',
#    'weight_kg': 29.5},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 495,
#    'capture_rate': '45'},
#   'meta_data': 15},
#  'Pidgey': {'abilities': "['Keen Eye', 'Tangled Feet', 'Big Pecks']",
#   'weakness': {'ghost': 0.0,
#    'grass': 0.5,
#    'ground': 0.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 45,
#    'defense': 40,
#    'experience_growth': 1059860,
#    'height_m': 0.3,
#    'hp': 40,
#    'sp_attack': 35,
#    'sp_defense': 35,
#    'speed': 56,
#    'type1': 'normal',
#    'type2': 'flying',
#    'weight_kg': 1.8},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 251,
#    'capture_rate': '255'},
#   'meta_data': 16},
#  'Pidgeotto': {'abilities': "['Keen Eye', 'Tangled Feet', 'Big Pecks']",
#   'weakness': {'ghost': 0.0,
#    'grass': 0.5,
#    'ground': 0.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 60,
#    'defense': 55,
#    'experience_growth': 1059860,
#    'height_m': 1.1,
#    'hp': 63,
#    'sp_attack': 50,
#    'sp_defense': 50,
#    'speed': 71,
#    'type1': 'normal',
#    'type2': 'flying',
#    'weight_kg': 30.0},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 349,
#    'capture_rate': '120'},
#   'meta_data': 17},
#  'Pidgeot': {'abilities': "['Keen Eye', 'Tangled Feet', 'Big Pecks']",
#   'weakness': {'ghost': 0.0,
#    'grass': 0.5,
#    'ground': 0.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 80,
#    'defense': 80,
#    'experience_growth': 1059860,
#    'height_m': 1.5,
#    'hp': 83,
#    'sp_attack': 135,
#    'sp_defense': 80,
#    'speed': 121,
#    'type1': 'normal',
#    'type2': 'flying',
#    'weight_kg': 39.5},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 579,
#    'capture_rate': '45'},
#   'meta_data': 18},
#  'Rattata': {'abilities': "['Run Away', 'Guts', 'Hustle', 'Gluttony', 'Hustle', 'Thick Fat']",
#   'weakness': {'ghost': 0.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 2.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 56,
#    'defense': 35,
#    'experience_growth': 1000000,
#    'height_m': nan,
#    'hp': 30,
#    'sp_attack': 25,
#    'sp_defense': 35,
#    'speed': 72,
#    'type1': 'normal',
#    'type2': 'dark',
#    'weight_kg': nan},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 253,
#    'capture_rate': '255'},
#   'meta_data': 19},
#  'Raticate': {'abilities': "['Run Away', 'Guts', 'Hustle', 'Gluttony', 'Hustle', 'Thick Fat']",
#   'weakness': {'ghost': 0.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 2.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 71,
#    'defense': 70,
#    'experience_growth': 1000000,
#    'height_m': nan,
#    'hp': 75,
#    'sp_attack': 40,
#    'sp_defense': 80,
#    'speed': 77,
#    'type1': 'normal',
#    'type2': 'dark',
#    'weight_kg': nan},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 413,
#    'capture_rate': '127'},
#   'meta_data': 20},
#  'Spearow': {'abilities': "['Keen Eye', 'Sniper']",
#   'weakness': {'ghost': 0.0,
#    'grass': 0.5,
#    'ground': 0.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 60,
#    'defense': 30,
#    'experience_growth': 1000000,
#    'height_m': 0.3,
#    'hp': 40,
#    'sp_attack': 31,
#    'sp_defense': 31,
#    'speed': 70,
#    'type1': 'normal',
#    'type2': 'flying',
#    'weight_kg': 2.0},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 262,
#    'capture_rate': '255'},
#   'meta_data': 21},
#  'Fearow': {'abilities': "['Keen Eye', 'Sniper']",
#   'weakness': {'ghost': 0.0,
#    'grass': 0.5,
#    'ground': 0.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 90,
#    'defense': 65,
#    'experience_growth': 1000000,
#    'height_m': 1.2,
#    'hp': 65,
#    'sp_attack': 61,
#    'sp_defense': 61,
#    'speed': 100,
#    'type1': 'normal',
#    'type2': 'flying',
#    'weight_kg': 38.0},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 442,
#    'capture_rate': '90'},
#   'meta_data': 22},
#  'Ekans': {'abilities': "['Intimidate', 'Shed Skin', 'Unnerve']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 60,
#    'defense': 44,
#    'experience_growth': 1000000,
#    'height_m': 2.0,
#    'hp': 35,
#    'sp_attack': 40,
#    'sp_defense': 54,
#    'speed': 55,
#    'type1': 'poison',
#    'type2': nan,
#    'weight_kg': 6.9},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 288,
#    'capture_rate': '255'},
#   'meta_data': 23},
#  'Arbok': {'abilities': "['Intimidate', 'Shed Skin', 'Unnerve']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 95,
#    'defense': 69,
#    'experience_growth': 1000000,
#    'height_m': 3.5,
#    'hp': 60,
#    'sp_attack': 65,
#    'sp_defense': 79,
#    'speed': 80,
#    'type1': 'poison',
#    'type2': nan,
#    'weight_kg': 65.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 448,
#    'capture_rate': '90'},
#   'meta_data': 24},
#  'Pikachu': {'abilities': "['Static', 'Lightningrod']",
#   'weakness': {'ghost': 1.0,
#    'grass': 1.0,
#    'ground': 2.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 0.5,
#    'water': 1.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 0.5,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 55,
#    'defense': 40,
#    'experience_growth': 1000000,
#    'height_m': 0.4,
#    'hp': 35,
#    'sp_attack': 50,
#    'sp_defense': 50,
#    'speed': 90,
#    'type1': 'electric',
#    'type2': nan,
#    'weight_kg': 6.0},
#   'base': {'base_egg_steps': 2560,
#    'base_happiness': 70,
#    'base_total': 320,
#    'capture_rate': '190'},
#   'meta_data': 25},
#  'Raichu': {'abilities': "['Static', 'Lightningrod', 'Surge Surfer']",
#   'weakness': {'ghost': 1.0,
#    'grass': 1.0,
#    'ground': 2.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 0.5,
#    'water': 1.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 0.5,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 85,
#    'defense': 50,
#    'experience_growth': 1000000,
#    'height_m': nan,
#    'hp': 60,
#    'sp_attack': 95,
#    'sp_defense': 85,
#    'speed': 110,
#    'type1': 'electric',
#    'type2': 'electric',
#    'weight_kg': nan},
#   'base': {'base_egg_steps': 2560,
#    'base_happiness': 70,
#    'base_total': 485,
#    'capture_rate': '75'},
#   'meta_data': 26},
#  'Sandshrew': {'abilities': "['Sand Veil', 'Sand Rush', 'Snow Cloak', 'Slush Rush']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 1.0,
#    'rock': 0.5,
#    'steel': 1.0,
#    'water': 2.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.0},
#   'stats': {'attack': 75,
#    'defense': 90,
#    'experience_growth': 1000000,
#    'height_m': nan,
#    'hp': 50,
#    'sp_attack': 10,
#    'sp_defense': 35,
#    'speed': 40,
#    'type1': 'ground',
#    'type2': 'ice',
#    'weight_kg': nan},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 300,
#    'capture_rate': '255'},
#   'meta_data': 27},
#  'Sandslash': {'abilities': "['Sand Veil', 'Sand Rush', 'Snow Cloak', 'Slush Rush']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 1.0,
#    'rock': 0.5,
#    'steel': 1.0,
#    'water': 2.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.0},
#   'stats': {'attack': 100,
#    'defense': 120,
#    'experience_growth': 1000000,
#    'height_m': nan,
#    'hp': 75,
#    'sp_attack': 25,
#    'sp_defense': 65,
#    'speed': 65,
#    'type1': 'ground',
#    'type2': 'ice',
#    'weight_kg': nan},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 450,
#    'capture_rate': '90'},
#   'meta_data': 28},
#  'Nidoran♀': {'abilities': "['Poison Point', 'Rivalry', 'Hustle']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 47,
#    'defense': 52,
#    'experience_growth': 1059860,
#    'height_m': 0.4,
#    'hp': 55,
#    'sp_attack': 40,
#    'sp_defense': 40,
#    'speed': 41,
#    'type1': 'poison',
#    'type2': nan,
#    'weight_kg': 7.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 275,
#    'capture_rate': '235'},
#   'meta_data': 29},
#  'Nidorina': {'abilities': "['Poison Point', 'Rivalry', 'Hustle']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 62,
#    'defense': 67,
#    'experience_growth': 1059860,
#    'height_m': 0.8,
#    'hp': 70,
#    'sp_attack': 55,
#    'sp_defense': 55,
#    'speed': 56,
#    'type1': 'poison',
#    'type2': nan,
#    'weight_kg': 20.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 365,
#    'capture_rate': '120'},
#   'meta_data': 30},
#  'Nidoqueen': {'abilities': "['Poison Point', 'Rivalry', 'Sheer Force']",
#   'weakness': {'ghost': 1.0,
#    'grass': 1.0,
#    'ground': 2.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 0.25,
#    'psychic': 2.0,
#    'rock': 0.5,
#    'steel': 1.0,
#    'water': 2.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.0},
#   'stats': {'attack': 92,
#    'defense': 87,
#    'experience_growth': 1059860,
#    'height_m': 1.3,
#    'hp': 90,
#    'sp_attack': 75,
#    'sp_defense': 85,
#    'speed': 76,
#    'type1': 'poison',
#    'type2': 'ground',
#    'weight_kg': 60.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 505,
#    'capture_rate': '45'},
#   'meta_data': 31},
#  'Nidoran♂': {'abilities': "['Poison Point', 'Rivalry', 'Hustle']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 57,
#    'defense': 40,
#    'experience_growth': 1059860,
#    'height_m': 0.5,
#    'hp': 46,
#    'sp_attack': 40,
#    'sp_defense': 40,
#    'speed': 50,
#    'type1': 'poison',
#    'type2': nan,
#    'weight_kg': 9.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 273,
#    'capture_rate': '235'},
#   'meta_data': 32},
#  'Nidorino': {'abilities': "['Poison Point', 'Rivalry', 'Hustle']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 72,
#    'defense': 57,
#    'experience_growth': 1059860,
#    'height_m': 0.9,
#    'hp': 61,
#    'sp_attack': 55,
#    'sp_defense': 55,
#    'speed': 65,
#    'type1': 'poison',
#    'type2': nan,
#    'weight_kg': 19.5},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 365,
#    'capture_rate': '120'},
#   'meta_data': 33},
#  'Nidoking': {'abilities': "['Poison Point', 'Rivalry', 'Sheer Force']",
#   'weakness': {'ghost': 1.0,
#    'grass': 1.0,
#    'ground': 2.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 0.25,
#    'psychic': 2.0,
#    'rock': 0.5,
#    'steel': 1.0,
#    'water': 2.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.0},
#   'stats': {'attack': 102,
#    'defense': 77,
#    'experience_growth': 1059860,
#    'height_m': 1.4,
#    'hp': 81,
#    'sp_attack': 85,
#    'sp_defense': 75,
#    'speed': 85,
#    'type1': 'poison',
#    'type2': 'ground',
#    'weight_kg': 62.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 505,
#    'capture_rate': '45'},
#   'meta_data': 34},
#  'Clefairy': {'abilities': "['Cute Charm', 'Magic Guard', 'Friend Guard']",
#   'weakness': {'ghost': 1.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 2.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 2.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 0.5,
#    'dragon': 0.0,
#    'electric': 1.0},
#   'stats': {'attack': 45,
#    'defense': 48,
#    'experience_growth': 800000,
#    'height_m': 0.6,
#    'hp': 70,
#    'sp_attack': 60,
#    'sp_defense': 65,
#    'speed': 35,
#    'type1': 'fairy',
#    'type2': nan,
#    'weight_kg': 7.5},
#   'base': {'base_egg_steps': 2560,
#    'base_happiness': 140,
#    'base_total': 323,
#    'capture_rate': '150'},
#   'meta_data': 35},
#  'Clefable': {'abilities': "['Cute Charm', 'Magic Guard', 'Unaware']",
#   'weakness': {'ghost': 1.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 2.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 2.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 0.5,
#    'dragon': 0.0,
#    'electric': 1.0},
#   'stats': {'attack': 70,
#    'defense': 73,
#    'experience_growth': 800000,
#    'height_m': 1.3,
#    'hp': 95,
#    'sp_attack': 95,
#    'sp_defense': 90,
#    'speed': 60,
#    'type1': 'fairy',
#    'type2': nan,
#    'weight_kg': 40.0},
#   'base': {'base_egg_steps': 2560,
#    'base_happiness': 140,
#    'base_total': 483,
#    'capture_rate': '25'},
#   'meta_data': 36},
#  'Vulpix': {'abilities': "['Flash Fire', 'Drought', 'Snow Cloak', 'Snow Warning']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 0.5,
#    'water': 2.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 41,
#    'defense': 40,
#    'experience_growth': 1000000,
#    'height_m': nan,
#    'hp': 38,
#    'sp_attack': 50,
#    'sp_defense': 65,
#    'speed': 65,
#    'type1': 'fire',
#    'type2': 'ice',
#    'weight_kg': nan},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 299,
#    'capture_rate': '190'},
#   'meta_data': 37},
#  'Ninetales': {'abilities': "['Flash Fire', 'Drought', 'Snow Cloak', 'Snow Warning']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 0.5,
#    'water': 2.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 67,
#    'defense': 75,
#    'experience_growth': 1000000,
#    'height_m': nan,
#    'hp': 73,
#    'sp_attack': 81,
#    'sp_defense': 100,
#    'speed': 109,
#    'type1': 'fire',
#    'type2': 'ice',
#    'weight_kg': nan},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 505,
#    'capture_rate': '75'},
#   'meta_data': 38},
#  'Jigglypuff': {'abilities': "['Cute Charm', 'Competitive', 'Friend Guard']",
#   'weakness': {'ghost': 0.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 2.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 2.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 0.5,
#    'dragon': 0.0,
#    'electric': 1.0},
#   'stats': {'attack': 45,
#    'defense': 20,
#    'experience_growth': 800000,
#    'height_m': 0.5,
#    'hp': 115,
#    'sp_attack': 45,
#    'sp_defense': 25,
#    'speed': 20,
#    'type1': 'normal',
#    'type2': 'fairy',
#    'weight_kg': 5.5},
#   'base': {'base_egg_steps': 2560,
#    'base_happiness': 70,
#    'base_total': 270,
#    'capture_rate': '170'},
#   'meta_data': 39},
#  'Wigglytuff': {'abilities': "['Cute Charm', 'Competitive', 'Frisk']",
#   'weakness': {'ghost': 0.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 2.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 2.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 0.5,
#    'dragon': 0.0,
#    'electric': 1.0},
#   'stats': {'attack': 70,
#    'defense': 45,
#    'experience_growth': 800000,
#    'height_m': 1.0,
#    'hp': 140,
#    'sp_attack': 85,
#    'sp_defense': 50,
#    'speed': 45,
#    'type1': 'normal',
#    'type2': 'fairy',
#    'weight_kg': 12.0},
#   'base': {'base_egg_steps': 2560,
#    'base_happiness': 70,
#    'base_total': 435,
#    'capture_rate': '50'},
#   'meta_data': 40},
#  'Zubat': {'abilities': "['Inner Focus', 'Infiltrator']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 0.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.25,
#    'fairy': 0.5,
#    'fight': 0.25,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 45,
#    'defense': 35,
#    'experience_growth': 1000000,
#    'height_m': 0.8,
#    'hp': 40,
#    'sp_attack': 30,
#    'sp_defense': 40,
#    'speed': 55,
#    'type1': 'poison',
#    'type2': 'flying',
#    'weight_kg': 7.5},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 245,
#    'capture_rate': '255'},
#   'meta_data': 41},
#  'Golbat': {'abilities': "['Inner Focus', 'Infiltrator']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 0.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.25,
#    'fairy': 0.5,
#    'fight': 0.25,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 80,
#    'defense': 70,
#    'experience_growth': 1000000,
#    'height_m': 1.6,
#    'hp': 75,
#    'sp_attack': 65,
#    'sp_defense': 75,
#    'speed': 90,
#    'type1': 'poison',
#    'type2': 'flying',
#    'weight_kg': 55.0},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 455,
#    'capture_rate': '90'},
#   'meta_data': 42},
#  'Oddish': {'abilities': "['Chlorophyll', 'Run Away']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 50,
#    'defense': 55,
#    'experience_growth': 1059860,
#    'height_m': 0.5,
#    'hp': 45,
#    'sp_attack': 75,
#    'sp_defense': 65,
#    'speed': 30,
#    'type1': 'grass',
#    'type2': 'poison',
#    'weight_kg': 5.4},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 320,
#    'capture_rate': '255'},
#   'meta_data': 43},
#  'Gloom': {'abilities': "['Chlorophyll', 'Stench']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 65,
#    'defense': 70,
#    'experience_growth': 1059860,
#    'height_m': 0.8,
#    'hp': 60,
#    'sp_attack': 85,
#    'sp_defense': 75,
#    'speed': 40,
#    'type1': 'grass',
#    'type2': 'poison',
#    'weight_kg': 8.6},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 395,
#    'capture_rate': '120'},
#   'meta_data': 44},
#  'Vileplume': {'abilities': "['Chlorophyll', 'Effect Spore']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 0.5,
#    'fight': 0.5,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 80,
#    'defense': 85,
#    'experience_growth': 1059860,
#    'height_m': 1.2,
#    'hp': 75,
#    'sp_attack': 110,
#    'sp_defense': 90,
#    'speed': 50,
#    'type1': 'grass',
#    'type2': 'poison',
#    'weight_kg': 18.6},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 490,
#    'capture_rate': '45'},
#   'meta_data': 45},
#  'Paras': {'abilities': "['Effect Spore', 'Dry Skin', 'Damp']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 0.25,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 2.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 2.0,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 4.0,
#    'flying': 4.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 70,
#    'defense': 55,
#    'experience_growth': 1000000,
#    'height_m': 0.3,
#    'hp': 35,
#    'sp_attack': 45,
#    'sp_defense': 55,
#    'speed': 25,
#    'type1': 'bug',
#    'type2': 'grass',
#    'weight_kg': 5.4},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 285,
#    'capture_rate': '190'},
#   'meta_data': 46},
#  'Parasect': {'abilities': "['Effect Spore', 'Dry Skin', 'Damp']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 0.25,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 2.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 2.0,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 4.0,
#    'flying': 4.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 95,
#    'defense': 80,
#    'experience_growth': 1000000,
#    'height_m': 1.0,
#    'hp': 60,
#    'sp_attack': 60,
#    'sp_defense': 80,
#    'speed': 30,
#    'type1': 'bug',
#    'type2': 'grass',
#    'weight_kg': 29.5},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 405,
#    'capture_rate': '75'},
#   'meta_data': 47},
#  'Venonat': {'abilities': "['Compoundeyes', 'Tinted Lens', 'Run Away']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.25,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 55,
#    'defense': 50,
#    'experience_growth': 1000000,
#    'height_m': 1.0,
#    'hp': 60,
#    'sp_attack': 40,
#    'sp_defense': 55,
#    'speed': 45,
#    'type1': 'bug',
#    'type2': 'poison',
#    'weight_kg': 30.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 305,
#    'capture_rate': '190'},
#   'meta_data': 48},
#  'Venomoth': {'abilities': "['Shield Dust', 'Tinted Lens', 'Wonder Skin ']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 2.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 0.25,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 65,
#    'defense': 60,
#    'experience_growth': 1000000,
#    'height_m': 1.5,
#    'hp': 70,
#    'sp_attack': 90,
#    'sp_defense': 75,
#    'speed': 90,
#    'type1': 'bug',
#    'type2': 'poison',
#    'weight_kg': 12.5},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 450,
#    'capture_rate': '75'},
#   'meta_data': 49},
#  'Diglett': {'abilities': "['Sand Veil', 'Arena Trap', 'Sand Force', 'Sand Veil', 'Tangling Hair', 'Sand Force']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 1.0,
#    'rock': 0.5,
#    'steel': 1.0,
#    'water': 2.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.0},
#   'stats': {'attack': 55,
#    'defense': 30,
#    'experience_growth': 1000000,
#    'height_m': nan,
#    'hp': 10,
#    'sp_attack': 35,
#    'sp_defense': 45,
#    'speed': 90,
#    'type1': 'ground',
#    'type2': 'ground',
#    'weight_kg': nan},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 265,
#    'capture_rate': '255'},
#   'meta_data': 50},
#  'Dugtrio': {'abilities': "['Sand Veil', 'Arena Trap', 'Sand Force', 'Sand Veil', 'Tangling Hair', 'Sand Force']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 0.5,
#    'psychic': 1.0,
#    'rock': 0.5,
#    'steel': 1.0,
#    'water': 2.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.0},
#   'stats': {'attack': 100,
#    'defense': 60,
#    'experience_growth': 1000000,
#    'height_m': nan,
#    'hp': 35,
#    'sp_attack': 50,
#    'sp_defense': 70,
#    'speed': 110,
#    'type1': 'ground',
#    'type2': 'ground',
#    'weight_kg': nan},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 425,
#    'capture_rate': '50'},
#   'meta_data': 51},
#  'Meowth': {'abilities': "['Pickup', 'Technician', 'Unnerve', 'Pickup', 'Technician', 'Rattled']",
#   'weakness': {'ghost': 0.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 2.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 35,
#    'defense': 35,
#    'experience_growth': 1000000,
#    'height_m': nan,
#    'hp': 40,
#    'sp_attack': 50,
#    'sp_defense': 40,
#    'speed': 90,
#    'type1': 'normal',
#    'type2': 'dark',
#    'weight_kg': nan},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 290,
#    'capture_rate': '255'},
#   'meta_data': 52},
#  'Persian': {'abilities': "['Limber', 'Technician', 'Unnerve', 'Fur Coat', 'Technician', 'Rattled']",
#   'weakness': {'ghost': 0.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 2.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 60,
#    'defense': 60,
#    'experience_growth': 1000000,
#    'height_m': nan,
#    'hp': 65,
#    'sp_attack': 75,
#    'sp_defense': 65,
#    'speed': 115,
#    'type1': 'normal',
#    'type2': 'dark',
#    'weight_kg': nan},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 440,
#    'capture_rate': '90'},
#   'meta_data': 53},
#  'Psyduck': {'abilities': "['Damp', 'Cloud Nine', 'Swift Swim']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 0.5,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 52,
#    'defense': 48,
#    'experience_growth': 1000000,
#    'height_m': 0.8,
#    'hp': 50,
#    'sp_attack': 65,
#    'sp_defense': 50,
#    'speed': 55,
#    'type1': 'water',
#    'type2': nan,
#    'weight_kg': 19.6},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 320,
#    'capture_rate': '190'},
#   'meta_data': 54},
#  'Golduck': {'abilities': "['Damp', 'Cloud Nine', 'Swift Swim']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 0.5,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 82,
#    'defense': 78,
#    'experience_growth': 1000000,
#    'height_m': 1.7,
#    'hp': 80,
#    'sp_attack': 95,
#    'sp_defense': 80,
#    'speed': 85,
#    'type1': 'water',
#    'type2': nan,
#    'weight_kg': 76.6},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 500,
#    'capture_rate': '75'},
#   'meta_data': 55},
#  'Mankey': {'abilities': "['Vital Spirit', 'Anger Point', 'Defiant']",
#   'weakness': {'ghost': 1.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 0.5,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 2.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 2.0,
#    'dark': 0.5,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 80,
#    'defense': 35,
#    'experience_growth': 1000000,
#    'height_m': 0.5,
#    'hp': 40,
#    'sp_attack': 35,
#    'sp_defense': 45,
#    'speed': 70,
#    'type1': 'fighting',
#    'type2': nan,
#    'weight_kg': 28.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 305,
#    'capture_rate': '190'},
#   'meta_data': 56},
#  'Primeape': {'abilities': "['Vital Spirit', 'Anger Point', 'Defiant']",
#   'weakness': {'ghost': 1.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 0.5,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 2.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 2.0,
#    'dark': 0.5,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 105,
#    'defense': 60,
#    'experience_growth': 1000000,
#    'height_m': 1.0,
#    'hp': 65,
#    'sp_attack': 60,
#    'sp_defense': 70,
#    'speed': 95,
#    'type1': 'fighting',
#    'type2': nan,
#    'weight_kg': 32.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 455,
#    'capture_rate': '75'},
#   'meta_data': 57},
#  'Growlithe': {'abilities': "['Intimidate', 'Flash Fire', 'Justified']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 0.5,
#    'water': 2.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 70,
#    'defense': 45,
#    'experience_growth': 1250000,
#    'height_m': 0.7,
#    'hp': 55,
#    'sp_attack': 70,
#    'sp_defense': 50,
#    'speed': 60,
#    'type1': 'fire',
#    'type2': nan,
#    'weight_kg': 19.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 350,
#    'capture_rate': '190'},
#   'meta_data': 58},
#  'Arcanine': {'abilities': "['Intimidate', 'Flash Fire', 'Justified']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 0.5,
#    'water': 2.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 110,
#    'defense': 80,
#    'experience_growth': 1250000,
#    'height_m': 1.9,
#    'hp': 90,
#    'sp_attack': 100,
#    'sp_defense': 80,
#    'speed': 95,
#    'type1': 'fire',
#    'type2': nan,
#    'weight_kg': 155.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 555,
#    'capture_rate': '75'},
#   'meta_data': 59},
#  'Poliwag': {'abilities': "['Water Absorb', 'Damp', 'Swift Swim']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 0.5,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 50,
#    'defense': 40,
#    'experience_growth': 1059860,
#    'height_m': 0.6,
#    'hp': 40,
#    'sp_attack': 40,
#    'sp_defense': 40,
#    'speed': 90,
#    'type1': 'water',
#    'type2': 'None',
#    'weight_kg': 12.4},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 300,
#    'capture_rate': '255'},
#   'meta_data': 60},
#  'Poliwhirl': {'abilities': "['Water Absorb', 'Damp', 'Swift Swim']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 0.5,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 65,
#    'defense': 65,
#    'experience_growth': 1059860,
#    'height_m': 1.0,
#    'hp': 65,
#    'sp_attack': 50,
#    'sp_defense': 50,
#    'speed': 90,
#    'type1': 'water',
#    'type2': nan,
#    'weight_kg': 20.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 385,
#    'capture_rate': '120'},
#   'meta_data': 61},
#  'Poliwrath': {'abilities': "['Water Absorb', 'Damp', 'Swift Swim']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 0.5,
#    'steel': 0.5,
#    'water': 0.5,
#    'bug': 0.5,
#    'fairy': 2.0,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 2.0,
#    'dark': 0.5,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 95,
#    'defense': 95,
#    'experience_growth': 1059860,
#    'height_m': 1.3,
#    'hp': 90,
#    'sp_attack': 70,
#    'sp_defense': 90,
#    'speed': 70,
#    'type1': 'water',
#    'type2': 'fighting',
#    'weight_kg': 54.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 510,
#    'capture_rate': '45'},
#   'meta_data': 62},
#  'Abra': {'abilities': "['Synchronize', 'Inner Focus', 'Magic Guard']",
#   'weakness': {'ghost': 2.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 0.5,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 2.0,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 2.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 20,
#    'defense': 15,
#    'experience_growth': 1059860,
#    'height_m': 0.9,
#    'hp': 25,
#    'sp_attack': 105,
#    'sp_defense': 55,
#    'speed': 90,
#    'type1': 'psychic',
#    'type2': nan,
#    'weight_kg': 19.5},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 310,
#    'capture_rate': '200'},
#   'meta_data': 63},
#  'Kadabra': {'abilities': "['Synchronize', 'Inner Focus', 'Magic Guard']",
#   'weakness': {'ghost': 2.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 0.5,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 2.0,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 2.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 35,
#    'defense': 30,
#    'experience_growth': 1059860,
#    'height_m': 1.3,
#    'hp': 40,
#    'sp_attack': 120,
#    'sp_defense': 70,
#    'speed': 105,
#    'type1': 'psychic',
#    'type2': 'None',
#    'weight_kg': 56.5},
#   'base': {'base_egg_steps': 5120,
# ...
#    'fight': 2.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 2.0,
#    'electric': 0.5},
#   'stats': {'attack': 60,
#    'defense': 85,
#    'experience_growth': 1000000,
#    'height_m': 3.0,
#    'hp': 78,
#    'sp_attack': 135,
#    'sp_defense': 91,
#    'speed': 36,
#    'type1': 'normal',
#    'type2': 'dragon',
#    'weight_kg': 185.0},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 485,
#    'capture_rate': '70'},
#   'meta_data': 780},
#  'Dhelmise': {'abilities': "['Steelworker']",
#   'weakness': {'ghost': 2.0,
#    'grass': 0.5,
#    'ground': 0.5,
#    'ice': 2.0,
#    'normal': 0.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 0.0,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 2.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 131,
#    'defense': 100,
#    'experience_growth': 1000000,
#    'height_m': 3.9,
#    'hp': 70,
#    'sp_attack': 86,
#    'sp_defense': 90,
#    'speed': 40,
#    'type1': 'ghost',
#    'type2': 'grass',
#    'weight_kg': 210.0},
#   'base': {'base_egg_steps': 6400,
#    'base_happiness': 70,
#    'base_total': 517,
#    'capture_rate': '25'},
#   'meta_data': 781},
#  'Jangmo-o': {'abilities': "['Bulletproof', 'Soundproof', 'Overcoat']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 2.0,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 2.0,
#    'electric': 0.5},
#   'stats': {'attack': 55,
#    'defense': 65,
#    'experience_growth': 1250000,
#    'height_m': 0.6,
#    'hp': 45,
#    'sp_attack': 45,
#    'sp_defense': 45,
#    'speed': 45,
#    'type1': 'dragon',
#    'type2': nan,
#    'weight_kg': 29.7},
#   'base': {'base_egg_steps': 10240,
#    'base_happiness': 70,
#    'base_total': 300,
#    'capture_rate': '45'},
#   'meta_data': 782},
#  'Hakamo-o': {'abilities': "['Bulletproof', 'Soundproof', 'Overcoat']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 0.5,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 0.5,
#    'fairy': 4.0,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 2.0,
#    'dark': 0.5,
#    'dragon': 2.0,
#    'electric': 0.5},
#   'stats': {'attack': 75,
#    'defense': 90,
#    'experience_growth': 1250000,
#    'height_m': 1.2,
#    'hp': 55,
#    'sp_attack': 65,
#    'sp_defense': 70,
#    'speed': 65,
#    'type1': 'dragon',
#    'type2': 'fighting',
#    'weight_kg': 47.0},
#   'base': {'base_egg_steps': 10240,
#    'base_happiness': 70,
#    'base_total': 420,
#    'capture_rate': '45'},
#   'meta_data': 783},
#  'Kommo-o': {'abilities': "['Bulletproof', 'Soundproof', 'Overcoat']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 0.5,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 0.5,
#    'fairy': 4.0,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 2.0,
#    'dark': 0.5,
#    'dragon': 2.0,
#    'electric': 0.5},
#   'stats': {'attack': 110,
#    'defense': 125,
#    'experience_growth': 1250000,
#    'height_m': 1.6,
#    'hp': 75,
#    'sp_attack': 100,
#    'sp_defense': 105,
#    'speed': 85,
#    'type1': 'dragon',
#    'type2': 'fighting',
#    'weight_kg': 78.2},
#   'base': {'base_egg_steps': 10240,
#    'base_happiness': 70,
#    'base_total': 600,
#    'capture_rate': '45'},
#   'meta_data': 784},
#  'Tapu Koko': {'abilities': "['Electric Surge', 'Telepathy']",
#   'weakness': {'ghost': 1.0,
#    'grass': 1.0,
#    'ground': 2.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 2.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 0.5,
#    'dark': 0.5,
#    'dragon': 0.0,
#    'electric': 0.5},
#   'stats': {'attack': 115,
#    'defense': 85,
#    'experience_growth': 1250000,
#    'height_m': 1.8,
#    'hp': 70,
#    'sp_attack': 95,
#    'sp_defense': 75,
#    'speed': 130,
#    'type1': 'electric',
#    'type2': 'fairy',
#    'weight_kg': 20.5},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 570,
#    'capture_rate': '3'},
#   'meta_data': 785},
#  'Tapu Lele': {'abilities': "['Psychic Surge', 'Telepathy']",
#   'weakness': {'ghost': 2.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 2.0,
#    'psychic': 0.5,
#    'rock': 1.0,
#    'steel': 2.0,
#    'water': 1.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 0.25,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 0.0,
#    'electric': 1.0},
#   'stats': {'attack': 85,
#    'defense': 75,
#    'experience_growth': 1250000,
#    'height_m': 1.2,
#    'hp': 70,
#    'sp_attack': 130,
#    'sp_defense': 115,
#    'speed': 95,
#    'type1': 'psychic',
#    'type2': 'fairy',
#    'weight_kg': 18.6},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 570,
#    'capture_rate': '3'},
#   'meta_data': 786},
#  'Tapu Bulu': {'abilities': "['Grassy Surge', 'Telepathy']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 0.5,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 4.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 2.0,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 0.5,
#    'dragon': 0.0,
#    'electric': 0.5},
#   'stats': {'attack': 130,
#    'defense': 115,
#    'experience_growth': 1250000,
#    'height_m': 1.9,
#    'hp': 70,
#    'sp_attack': 85,
#    'sp_defense': 95,
#    'speed': 75,
#    'type1': 'grass',
#    'type2': 'fairy',
#    'weight_kg': 45.5},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 570,
#    'capture_rate': '3'},
#   'meta_data': 787},
#  'Tapu Fini': {'abilities': "['Misty Surge', 'Telepathy']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 2.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 0.5,
#    'dragon': 0.0,
#    'electric': 2.0},
#   'stats': {'attack': 75,
#    'defense': 115,
#    'experience_growth': 1250000,
#    'height_m': 1.3,
#    'hp': 70,
#    'sp_attack': 95,
#    'sp_defense': 130,
#    'speed': 85,
#    'type1': 'water',
#    'type2': 'fairy',
#    'weight_kg': 21.2},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 570,
#    'capture_rate': '3'},
#   'meta_data': 788},
#  'Cosmog': {'abilities': "['Unaware']",
#   'weakness': {'ghost': 2.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 0.5,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 2.0,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 2.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 29,
#    'defense': 31,
#    'experience_growth': 1250000,
#    'height_m': 0.2,
#    'hp': 43,
#    'sp_attack': 29,
#    'sp_defense': 31,
#    'speed': 37,
#    'type1': 'psychic',
#    'type2': nan,
#    'weight_kg': 0.1},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 200,
#    'capture_rate': '45'},
#   'meta_data': 789},
#  'Cosmoem': {'abilities': "['Sturdy']",
#   'weakness': {'ghost': 2.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 0.5,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 2.0,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 2.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 29,
#    'defense': 131,
#    'experience_growth': 1250000,
#    'height_m': 0.1,
#    'hp': 43,
#    'sp_attack': 29,
#    'sp_defense': 131,
#    'speed': 37,
#    'type1': 'psychic',
#    'type2': nan,
#    'weight_kg': 999.9},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 400,
#    'capture_rate': '45'},
#   'meta_data': 790},
#  'Solgaleo': {'abilities': "['Full Metal Body']",
#   'weakness': {'ghost': 2.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 0.5,
#    'normal': 0.5,
#    'poison': 0.0,
#    'psychic': 0.25,
#    'rock': 0.5,
#    'steel': 0.5,
#    'water': 1.0,
#    'bug': 1.0,
#    'fairy': 0.5,
#    'fight': 1.0,
#    'fire': 2.0,
#    'flying': 0.5,
#    'dark': 2.0,
#    'dragon': 0.5,
#    'electric': 1.0},
#   'stats': {'attack': 137,
#    'defense': 107,
#    'experience_growth': 1250000,
#    'height_m': 3.4,
#    'hp': 137,
#    'sp_attack': 113,
#    'sp_defense': 89,
#    'speed': 97,
#    'type1': 'psychic',
#    'type2': 'steel',
#    'weight_kg': 230.0},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 680,
#    'capture_rate': '45'},
#   'meta_data': 791},
#  'Lunala': {'abilities': "['Shadow Shield']",
#   'weakness': {'ghost': 4.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 0.0,
#    'poison': 0.5,
#    'psychic': 0.5,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 0.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 4.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 113,
#    'defense': 89,
#    'experience_growth': 1250000,
#    'height_m': 4.0,
#    'hp': 137,
#    'sp_attack': 137,
#    'sp_defense': 107,
#    'speed': 97,
#    'type1': 'psychic',
#    'type2': 'ghost',
#    'weight_kg': 120.0},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 680,
#    'capture_rate': '45'},
#   'meta_data': 792},
#  'Nihilego': {'abilities': "['Beast Boost']",
#   'weakness': {'ghost': 1.0,
#    'grass': 1.0,
#    'ground': 4.0,
#    'ice': 1.0,
#    'normal': 0.5,
#    'poison': 0.25,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 2.0,
#    'water': 2.0,
#    'bug': 0.5,
#    'fairy': 0.5,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 0.5,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 53,
#    'defense': 47,
#    'experience_growth': 1250000,
#    'height_m': 1.2,
#    'hp': 109,
#    'sp_attack': 127,
#    'sp_defense': 131,
#    'speed': 103,
#    'type1': 'rock',
#    'type2': 'poison',
#    'weight_kg': 55.5},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 570,
#    'capture_rate': '45'},
#   'meta_data': 793},
#  'Buzzwole': {'abilities': "['Beast Boost']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 0.5,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 2.0,
#    'fight': 0.5,
#    'fire': 2.0,
#    'flying': 4.0,
#    'dark': 0.5,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 139,
#    'defense': 139,
#    'experience_growth': 1250000,
#    'height_m': 2.4,
#    'hp': 107,
#    'sp_attack': 53,
#    'sp_defense': 53,
#    'speed': 79,
#    'type1': 'bug',
#    'type2': 'fighting',
#    'weight_kg': 333.6},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 570,
#    'capture_rate': '25'},
#   'meta_data': 794},
#  'Pheromosa': {'abilities': "['Beast Boost']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 0.5,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 2.0,
#    'fight': 0.5,
#    'fire': 2.0,
#    'flying': 4.0,
#    'dark': 0.5,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 137,
#    'defense': 37,
#    'experience_growth': 1250000,
#    'height_m': 1.8,
#    'hp': 71,
#    'sp_attack': 137,
#    'sp_defense': 37,
#    'speed': 151,
#    'type1': 'bug',
#    'type2': 'fighting',
#    'weight_kg': 25.0},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 570,
#    'capture_rate': '255'},
#   'meta_data': 795},
#  'Xurkitree': {'abilities': "['Beast Boost']",
#   'weakness': {'ghost': 1.0,
#    'grass': 1.0,
#    'ground': 2.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 0.5,
#    'water': 1.0,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 0.5,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 89,
#    'defense': 71,
#    'experience_growth': 1250000,
#    'height_m': 3.8,
#    'hp': 83,
#    'sp_attack': 173,
#    'sp_defense': 71,
#    'speed': 83,
#    'type1': 'electric',
#    'type2': nan,
#    'weight_kg': 100.0},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 570,
#    'capture_rate': '30'},
#   'meta_data': 796},
#  'Celesteela': {'abilities': "['Beast Boost']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 0.0,
#    'ice': 1.0,
#    'normal': 0.5,
#    'poison': 0.0,
#    'psychic': 0.5,
#    'rock': 1.0,
#    'steel': 0.5,
#    'water': 1.0,
#    'bug': 0.25,
#    'fairy': 0.5,
#    'fight': 1.0,
#    'fire': 2.0,
#    'flying': 0.5,
#    'dark': 1.0,
#    'dragon': 0.5,
#    'electric': 2.0},
#   'stats': {'attack': 101,
#    'defense': 103,
#    'experience_growth': 1250000,
#    'height_m': 9.2,
#    'hp': 97,
#    'sp_attack': 107,
#    'sp_defense': 101,
#    'speed': 61,
#    'type1': 'steel',
#    'type2': 'flying',
#    'weight_kg': 999.9},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 570,
#    'capture_rate': '25'},
#   'meta_data': 797},
#  'Kartana': {'abilities': "['Beast Boost']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.25,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 0.5,
#    'poison': 0.0,
#    'psychic': 0.5,
#    'rock': 0.5,
#    'steel': 0.5,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 0.5,
#    'fight': 2.0,
#    'fire': 4.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 0.5,
#    'electric': 0.5},
#   'stats': {'attack': 181,
#    'defense': 131,
#    'experience_growth': 1250000,
#    'height_m': 0.3,
#    'hp': 59,
#    'sp_attack': 59,
#    'sp_defense': 31,
#    'speed': 109,
#    'type1': 'grass',
#    'type2': 'steel',
#    'weight_kg': 0.1},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 570,
#    'capture_rate': '255'},
#   'meta_data': 798},
#  'Guzzlord': {'abilities': "['Beast Boost']",
#   'weakness': {'ghost': 0.5,
#    'grass': 0.5,
#    'ground': 1.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 0.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 2.0,
#    'fairy': 4.0,
#    'fight': 2.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 0.5,
#    'dragon': 2.0,
#    'electric': 0.5},
#   'stats': {'attack': 101,
#    'defense': 53,
#    'experience_growth': 1250000,
#    'height_m': 5.5,
#    'hp': 223,
#    'sp_attack': 97,
#    'sp_defense': 53,
#    'speed': 43,
#    'type1': 'dark',
#    'type2': 'dragon',
#    'weight_kg': 888.0},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 570,
#    'capture_rate': '15'},
#   'meta_data': 799},
#  'Necrozma': {'abilities': "['Prism Armor']",
#   'weakness': {'ghost': 2.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 0.5,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 2.0,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 2.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 107,
#    'defense': 101,
#    'experience_growth': 1250000,
#    'height_m': 2.4,
#    'hp': 97,
#    'sp_attack': 127,
#    'sp_defense': 89,
#    'speed': 79,
#    'type1': 'psychic',
#    'type2': nan,
#    'weight_kg': 230.0},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 600,
#    'capture_rate': '3'},
#   'meta_data': 800},
#  'Magearna': {'abilities': "['Soul-Heart']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 0.5,
#    'normal': 0.5,
#    'poison': 0.0,
#    'psychic': 0.5,
#    'rock': 0.5,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.25,
#    'fairy': 0.5,
#    'fight': 1.0,
#    'fire': 2.0,
#    'flying': 0.5,
#    'dark': 0.5,
#    'dragon': 0.0,
#    'electric': 1.0},
#   'stats': {'attack': 95,
#    'defense': 115,
#    'experience_growth': 1250000,
#    'height_m': 1.0,
#    'hp': 80,
#    'sp_attack': 130,
#    'sp_defense': 115,
#    'speed': 65,
#    'type1': 'steel',
#    'type2': 'fairy',
#    'weight_kg': 80.5},
#   'base': {'base_egg_steps': 30720,
#    'base_happiness': 0,
#    'base_total': 600,
#    'capture_rate': '3'},
#   'meta_data': 801}}

# %% [markdown]
# ### Let's create a new dictionary called ```joels_pokemon```.
#
# To do this, we will:
# 1. Create an empty dictionary called ```joels_pokemon```
# 2. Loop over the names in the ```joels_pokemon_names``` list
# 3. Use the name to access the pokemon's information in the ```data``` dictionary
# 4. Add the pokemon name to the ```joels_pokemon``` dictionary as a ```key``` and the pokemon's information as the key's ```value```

# %%
# Your code here

joels_pokemon = {}
for name in joels_pokemon_names:
    joels_pokemon[name] = data[name] #additional method: joel_pokemon.update({pokemon: data[pokemon]})

joels_pokemon
# Out:
# {'Bayleef': {'abilities': "['Overgrow', 'Leaf Guard']",
#   'weakness': {'ghost': 1.0,
#    'grass': 0.5,
#    'ground': 0.5,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 2.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 0.5,
#    'bug': 2.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 2.0,
#    'flying': 2.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 0.5},
#   'stats': {'attack': 62,
#    'defense': 80,
#    'experience_growth': 1059860,
#    'height_m': 1.2,
#    'hp': 60,
#    'sp_attack': 63,
#    'sp_defense': 80,
#    'speed': 60,
#    'type1': 'grass',
#    'type2': 'None',
#    'weight_kg': 15.8},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 405,
#    'capture_rate': '45'},
#   'meta_data': 153},
#  'Haunter': {'abilities': "['Levitate']",
#   'weakness': {'ghost': 2.0,
#    'grass': 0.5,
#    'ground': 2.0,
#    'ice': 1.0,
#    'normal': 0.0,
#    'poison': 0.25,
#    'psychic': 2.0,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.25,
#    'fairy': 0.5,
#    'fight': 0.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 2.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 50,
#    'defense': 45,
#    'experience_growth': 1059860,
#    'height_m': 1.6,
#    'hp': 45,
#    'sp_attack': 115,
#    'sp_defense': 55,
#    'speed': 95,
#    'type1': 'ghost',
#    'type2': 'poison',
#    'weight_kg': 0.1},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 405,
#    'capture_rate': '90'},
#   'meta_data': 93},
#  'Poliwag': {'abilities': "['Water Absorb', 'Damp', 'Swift Swim']",
#   'weakness': {'ghost': 1.0,
#    'grass': 2.0,
#    'ground': 1.0,
#    'ice': 0.5,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 1.0,
#    'steel': 0.5,
#    'water': 0.5,
#    'bug': 1.0,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 0.5,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 50,
#    'defense': 40,
#    'experience_growth': 1059860,
#    'height_m': 0.6,
#    'hp': 40,
#    'sp_attack': 40,
#    'sp_defense': 40,
#    'speed': 90,
#    'type1': 'water',
#    'type2': 'None',
#    'weight_kg': 12.4},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 300,
#    'capture_rate': '255'},
#   'meta_data': 60},
#  'Pidgeotto': {'abilities': "['Keen Eye', 'Tangled Feet', 'Big Pecks']",
#   'weakness': {'ghost': 0.0,
#    'grass': 0.5,
#    'ground': 0.0,
#    'ice': 2.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 1.0,
#    'rock': 2.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 0.5,
#    'fairy': 1.0,
#    'fight': 1.0,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 1.0,
#    'dragon': 1.0,
#    'electric': 2.0},
#   'stats': {'attack': 60,
#    'defense': 55,
#    'experience_growth': 1059860,
#    'height_m': 1.1,
#    'hp': 63,
#    'sp_attack': 50,
#    'sp_defense': 50,
#    'speed': 71,
#    'type1': 'normal',
#    'type2': 'flying',
#    'weight_kg': 30.0},
#   'base': {'base_egg_steps': 3840,
#    'base_happiness': 70,
#    'base_total': 349,
#    'capture_rate': '120'},
#   'meta_data': 17},
#  'Kadabra': {'abilities': "['Synchronize', 'Inner Focus', 'Magic Guard']",
#   'weakness': {'ghost': 2.0,
#    'grass': 1.0,
#    'ground': 1.0,
#    'ice': 1.0,
#    'normal': 1.0,
#    'poison': 1.0,
#    'psychic': 0.5,
#    'rock': 1.0,
#    'steel': 1.0,
#    'water': 1.0,
#    'bug': 2.0,
#    'fairy': 1.0,
#    'fight': 0.5,
#    'fire': 1.0,
#    'flying': 1.0,
#    'dark': 2.0,
#    'dragon': 1.0,
#    'electric': 1.0},
#   'stats': {'attack': 35,
#    'defense': 30,
#    'experience_growth': 1059860,
#    'height_m': 1.3,
#    'hp': 40,
#    'sp_attack': 120,
#    'sp_defense': 70,
#    'speed': 105,
#    'type1': 'psychic',
#    'type2': 'None',
#    'weight_kg': 56.5},
#   'base': {'base_egg_steps': 5120,
#    'base_happiness': 70,
#    'base_total': 400,
#    'capture_rate': '100'},
#   'meta_data': 64}}

# %% [markdown]
# Run the cell below to see if you successfully made the joels_pokemon dictionary!

# %%
from tests import CheckDictionary

test = CheckDictionary(joels_pokemon)
test.run()
# Out:
# # ✅ Your dictionary passed 2 out of 2 tests!
#
# >✅ *Dictionary Keys are correct!*
#
# >✅ *Dictionary data are correct!*

# %% [markdown]
# # Visualization
#
# Let's figure out which pokemon is Joél's strongest pokemon!
#
# <u>In the cell below</u>
#
# - Create a  bar plot for that shows the attack stat for each of joel's 5 pokemon.
# - Give the plot the following title: `Joel's pokemon stats`.

# %%
# Your code here

attacks = []
for key in joels_pokemon:
    attacks.append(joels_pokemon[key]['stats']['attack'])
    
#list comprehension: attacks = [joels_pokemon[name]['stats']['attack'] for name in joels_pokemon]

names = list(joels_pokemon)

import matplotlib.pyplot as plt

plt.bar(names, attacks)
plt.title('Joél\'s pokemon stats');

# %% [markdown]
# > **Sierra's Addition:** here's the breakdown for list comprehension - the thing that you want to be in the list **for** a variable **in** an iterable

# %% [markdown]
# **What if we wanted to sort the graph?**
#
# There is a couple ways we can do this, but a useful way of doing it would be to sort the dictionary itself!

# %%
sorted_dict = dict(sorted(joels_pokemon.items(), key=lambda item: item[1]['stats']['attack']))

attack_stats = [sorted_dict[pokemon]['stats']['attack'] for pokemon in sorted_dict]
names = list(sorted_dict)

plt.bar(names, attack_stats)
plt.title("Joél's pokemon stats");

# %% [markdown]
# ![](https://gamepress.gg/pokemonmasters/sites/pokemonmasters/files/styles/300h/public/2019-08/pm0153_00_bayleaf_256.ktx.png?itok=Tr7OMsm1)

# %% [markdown]
# **Bayleef** is Joél's strongest pokemon. Let's create a list of all Pokemon that Bayleef is weak against.
#
# Our dictionary gives us the *Types* of pokemon Bayleef is weak to. Our dictionary also gives us the type for each pokemon. So first we have to figure out what types of pokemon Bayleef is weak to, then grab every pokemon that has that type.
#
# **Ok, here is how we will do it.**
#
# *Weakness* is measured with the ```weakness``` key in our data. If the weakness value = 2, that means the pokemon is extremely weak to that type of pokemon.
#
# To find all pokemon that Bayleef is weak to, we have to:
# 1. Isolate Bayleef's weakness data from our dictionary
# 2. Identify any type that has a weakness score of 2 and append those types to a list called ```weakness_types```
# 3. Loop over our entire dataset
# 4. Identify pokemon who have a type that match the types in our ```weakness_types``` list.
# > **Hint** The type of each pokemon can be found using the ```stats``` key
# 5. Append the names of those pokemon to a list called ```bayleef_weakness```
#
# -----------------
#
# **Let's walk through steps 1 and 2.**
#
# You will code steps 3-5!

# %% [markdown]
# **Step 1:** Isolate Bayleef's weakness data from our dictionary

# %%
joels_pokemon['Bayleef']
# Out:
# {'abilities': "['Overgrow', 'Leaf Guard']",
#  'weakness': {'ghost': 1.0,
#   'grass': 0.5,
#   'ground': 0.5,
#   'ice': 2.0,
#   'normal': 1.0,
#   'poison': 2.0,
#   'psychic': 1.0,
#   'rock': 1.0,
#   'steel': 1.0,
#   'water': 0.5,
#   'bug': 2.0,
#   'fairy': 1.0,
#   'fight': 1.0,
#   'fire': 2.0,
#   'flying': 2.0,
#   'dark': 1.0,
#   'dragon': 1.0,
#   'electric': 0.5},
#  'stats': {'attack': 62,
#   'defense': 80,
#   'experience_growth': 1059860,
#   'height_m': 1.2,
#   'hp': 60,
#   'sp_attack': 63,
#   'sp_defense': 80,
#   'speed': 60,
#   'type1': 'grass',
#   'type2': 'None',
#   'weight_kg': 15.8},
#  'base': {'base_egg_steps': 5120,
#   'base_happiness': 70,
#   'base_total': 405,
#   'capture_rate': '45'},
#  'meta_data': 153}

# %%
bayleef_weakness_scores = data['Bayleef']['weakness']
bayleef_weakness_scores
# Out:
# {'ghost': 1.0,
#  'grass': 0.5,
#  'ground': 0.5,
#  'ice': 2.0,
#  'normal': 1.0,
#  'poison': 2.0,
#  'psychic': 1.0,
#  'rock': 1.0,
#  'steel': 1.0,
#  'water': 0.5,
#  'bug': 2.0,
#  'fairy': 1.0,
#  'fight': 1.0,
#  'fire': 2.0,
#  'flying': 2.0,
#  'dark': 1.0,
#  'dragon': 1.0,
#  'electric': 0.5}

# %% [markdown]
# **Step 2:** Identify any type that has a weakness score of 2 and appending those types to a list called ```weakness_types```
#
#
# We do this by:
# 1. Creating an empty list
# 2. Looping over the keys of our newly made dictionary```bayleef_weakness_score```.
#     - Each key is a pokemon type
# 3. Checking if the score equals 2
# 4. Appending the key to our empty list if the score equals 2

# %%
weakness_types = []

for weakness in bayleef_weakness_scores.keys():
    if bayleef_weakness_scores[weakness] == 2:
        weakness_types.append(weakness)
        
weakness_types
# Out:
# ['ice', 'poison', 'bug', 'fire', 'flying']

# %% [markdown]
# Bayleef is weak to ice, poison, bug, fire, and flying pokemon.
#
#
# # Now your turn.
#
# In the cell below, use the weakness_types list to identify pokemon that have one of those types, and append those pokemon to a list named ```bayleef_weakness```.
#
# >**Hint** The code will be very similar to the code for step 2.
#
# >**Hint** Make sure your list doesn't contain duplicates of the same pokemon!

# %%
# Your code here

bayleef_weakness = set()
for key in data.keys():
    if data[key]['stats']['type1'] in weakness_types:
        bayleef_weakness.add(key)
    elif data[key]['stats']['type2'] in weakness_types:
        bayleef_weakness.add(key)
        
bayleef_weakness = list(bayleef_weakness)

bayleef_weakness
# Out:
# ['Cubchoo',
#  'Croagunk',
#  'Silcoon',
#  'Ho-Oh',
#  'Vanillite',
#  'Combusken',
#  'Moltres',
#  'Pelipper',
#  'Chandelure',
#  'Gliscor',
#  'Zubat',
#  'Wingull',
#  'Victini',
#  'Anorith',
#  'Glaceon',
#  'Magmar',
#  'Emboar',
#  'Charizard',
#  'Weepinbell',
#  'Venusaur',
#  'Mantine',
#  'Tentacruel',
#  'Koffing',
#  'Cloyster',
#  'Salamence',
#  'Pignite',
#  'Growlithe',
#  'Xatu',
#  'Mamoswine',
#  'Darumaka',
#  'Quilava',
#  'Scolipede',
#  'Weedle',
#  'Litleo',
#  'Pidgeotto',
#  'Oddish',
#  'Simisear',
#  'Murkrow',
#  'Gligar',
#  'Woobat',
#  'Swoobat',
#  'Bergmite',
#  'Vivillon',
#  'Foongus',
#  'Nidoking',
#  'Staraptor',
#  'Butterfree',
#  'Nidorino',
#  'Dodrio',
#  'Sandshrew',
#  'Sewaddle',
#  'Vanilluxe',
#  'Archen',
#  'Nincada',
#  'Sigilyph',
#  'Emolga',
#  'Stunky',
#  'Gyarados',
#  'Magmortar',
#  'Swadloon',
#  'Beartic',
#  'Mandibuzz',
#  'Trumbeak',
#  'Charmeleon',
#  'Darmanitan',
#  'Blaziken',
#  'Skiploom',
#  'Avalugg',
#  'Houndoom',
#  'Camerupt',
#  'Hawlucha',
#  'Vulpix',
#  'Yanmega',
#  'Nidorina',
#  'Dragonite',
#  'Wurmple',
#  'Skuntank',
#  'Sneasel',
#  'Dragalge',
#  'Gastly',
#  'Slugma',
#  'Doduo',
#  'Ivysaur',
#  'Qwilfish',
#  'Skarmory',
#  'Spewpa',
#  'Combee',
#  'Surskit',
#  'Noivern',
#  'Gengar',
#  'Forretress',
#  'Smoochum',
#  'Roselia',
#  'Starly',
#  'Jynx',
#  'Snorunt',
#  'Durant',
#  'Delibird',
#  'Wimpod',
#  'Hoppip',
#  'Dewgong',
#  'Kricketune',
#  'Karrablast',
#  'Volcarona',
#  'Bulbasaur',
#  'Nidoran♀',
#  'Altaria',
#  'Rayquaza',
#  'Venonat',
#  'Kricketot',
#  'Ekans',
#  'Pidove',
#  'Arcanine',
#  'Pidgeot',
#  'Flareon',
#  'Dwebble',
#  'Aurorus',
#  'Fletchling',
#  'Weavile',
#  'Arbok',
#  'Golisopod',
#  'Muk',
#  'Reshiram',
#  'Fletchinder',
#  'Spinarak',
#  'Swanna',
#  'Venomoth',
#  'Pinsir',
#  'Hoothoot',
#  'Swalot',
#  'Marowak',
#  'Cyndaquil',
#  'Burmy',
#  'Venipede',
#  'Grubbin',
#  'Vanillish',
#  'Armaldo',
#  'Pidgey',
#  'Shuckle',
#  'Drapion',
#  'Noibat',
#  'Volbeat',
#  'Celesteela',
#  'Budew',
#  'Wormadam',
#  'Skrelp',
#  'Whirlipede',
#  'Numel',
#  'Spearow',
#  'Noctowl',
#  'Regice',
#  'Chimchar',
#  'Piloswine',
#  'Bellsprout',
#  'Tranquill',
#  'Larvesta',
#  'Scizor',
#  'Golbat',
#  'Sealeo',
#  'Beedrill',
#  'Cryogonal',
#  'Litten',
#  'Pineco',
#  'Houndour',
#  'Swablu',
#  'Seviper',
#  'Torkoal',
#  'Roserade',
#  'Landorus',
#  'Pheromosa',
#  'Nidoqueen',
#  'Garbodor',
#  'Articuno',
#  'Amaura',
#  'Braixen',
#  'Illumise',
#  'Ledian',
#  'Vileplume',
#  'Weezing',
#  'Torchic',
#  'Nihilego',
#  'Haunter',
#  'Crustle',
#  'Tropius',
#  'Delphox',
#  'Magcargo',
#  'Oricorio',
#  'Mothim',
#  'Entei',
#  'Charjabug',
#  'Accelgor',
#  'Turtonator',
#  'Swellow',
#  'Infernape',
#  'Heatmor',
#  'Natu',
#  'Monferno',
#  'Joltik',
#  'Dustox',
#  'Litwick',
#  'Chatot',
#  'Incineroar',
#  'Ninetales',
#  'Walrein',
#  'Amoonguss',
#  'Lampent',
#  "Farfetch'd",
#  'Togekiss',
#  'Honchkrow',
#  'Kyurem',
#  'Araquanid',
#  'Charmander',
#  'Scyther',
#  'Jumpluff',
#  'Galvantula',
#  'Taillow',
#  'Swinub',
#  'Ariados',
#  'Staravia',
#  'Abomasnow',
#  'Fennekin',
#  'Pikipek',
#  'Kakuna',
#  'Beautifly',
#  'Leavanny',
#  'Froslass',
#  'Pansear',
#  'Ducklett',
#  'Rufflet',
#  'Salazzle',
#  'Gulpin',
#  'Gloom',
#  'Rapidash',
#  'Yveltal',
#  'Talonflame',
#  'Fearow',
#  'Yanma',
#  'Heatran',
#  'Cutiefly',
#  'Crobat',
#  'Grimer',
#  'Archeops',
#  'Toucannon',
#  'Ponyta',
#  'Tentacool',
#  'Rowlet',
#  'Braviary',
#  'Sandslash',
#  'Torracat',
#  'Toxapex',
#  'Ribombee',
#  'Nidoran♂',
#  'Mantyke',
#  'Dartrix',
#  'Skorupi',
#  'Heracross',
#  'Togetic',
#  'Trubbish',
#  'Snover',
#  'Zapdos',
#  'Typhlosion',
#  'Pyroar',
#  'Paras',
#  'Scatterbug',
#  'Minior',
#  'Buzzwole',
#  'Metapod',
#  'Ninjask',
#  'Cascoon',
#  'Ledyba',
#  'Drifloon',
#  'Magby',
#  'Tepig',
#  'Vespiquen',
#  'Shelmet',
#  'Drifblim',
#  'Toxicroak',
#  'Volcanion',
#  'Shedinja',
#  'Crabominable',
#  'Genesect',
#  'Glalie',
#  'Spheal',
#  'Escavalier',
#  'Aerodactyl',
#  'Unfezant',
#  'Thundurus',
#  'Mareanie',
#  'Vullaby',
#  'Caterpie',
#  'Lapras',
#  'Victreebel',
#  'Parasect',
#  'Tornadus',
#  'Salandit',
#  'Lugia',
#  'Masquerain',
#  'Vikavolt',
#  'Dewpider']

# %% [markdown]
# Run the cell below to test your code! ⬇️

# %%
from tests import ListCheck
test = ListCheck(bayleef_weakness)
test.run()
# Out:
# # Your list passed 2 out of 2 tests!
#
# >✅ *List length is correct!*
#
# >✅ *List data are correct*
